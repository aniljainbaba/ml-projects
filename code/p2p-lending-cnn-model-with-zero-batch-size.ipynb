# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams
import glob
from sklearn.preprocessing import LabelEncoder
from matplotlib import rcParams
from scipy import stats
import openpyxl

# %%
# get data file names
path =r'.'
filenames = glob.glob(path + "/data/LoanStats_securev1_2019Q1.csv.zip")

# %%
dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename,skiprows=1,low_memory=False))
# Concatenate all data into one DataFrame
big_frame = pd.concat(dfs, ignore_index=True)

# %%
# read input csv zip files
path =r'.'
dfs = []
filenames = glob.glob(path + "/data/*.zip")
print(filenames)
for zipFileName in filenames:
    print(zipFileName)
    try:
        df = pd.read_csv(zipFileName,skiprows=1,low_memory=False)
        print("records count for file ", zipFileName, " = ",df.shape[0])
        dfs.append(df) 
        # Concatenate all data into one DataFrame
        big_frame = pd.concat(dfs, ignore_index=True)
    except KeyError:
        print ('ERROR: not able to read  %s  zip file',zipFileName)
    else:
        print ('able to read  %s  zip file',zipFileName)    

print("Reading, Extracting input zip files done...")
# Out:
# ['./data_final/LoanStats_securev1_2018Q4.csv.zip', './data_final/LoanStats_securev1_2017Q4.csv.zip', './data_final/LoanStats_securev1_2017Q3.csv.zip', './data_final/LoanStats_securev1_2016Q3.csv.zip', './data_final/LoanStats_securev1_2020Q1.csv.zip', './data_final/LoanStats_securev1_2019Q2.csv.zip', './data_final/LoanStats_securev1_2016Q1.csv.zip', './data_final/LoanStats_securev1_2019Q1.csv.zip', './data_final/LoanStats_securev1_2016Q4.csv.zip', './data_final/LoanStats_securev1_2019Q4.csv.zip', './data_final/LoanStats_securev1_2017Q2.csv.zip', './data_final/LoanStats_securev1_2019Q3.csv.zip', './data_final/LoanStats_securev1_2016Q2.csv.zip', './data_final/LoanStats_securev1_2018Q2.csv.zip', './data_final/LoanStats_securev1_2017Q1.csv.zip', './data_final/LoanStats_securev1_2018Q1.csv.zip', './data_final/LoanStats_securev1_2018Q3.csv.zip']
# ./data_final/LoanStats_securev1_2018Q4.csv.zip
# records count for file  ./data_final/LoanStats_securev1_2018Q4.csv.zip  =  128414
# able to read  %s  zip file ./data_final/LoanStats_securev1_2018Q4.csv.zip
# ./data_final/LoanStats_securev1_2017Q4.csv.zip
# records count for file  ./data_final/LoanStats_securev1_2017Q4.csv.zip  =  118650
# able to read  %s  zip file ./data_final/LoanStats_securev1_2017Q4.csv.zip
# ./data_final/LoanStats_securev1_2017Q3.csv.zip
# records count for file  ./data_final/LoanStats_securev1_2017Q3.csv.zip  =  122703
# able to read  %s  zip file ./data_final/LoanStats_securev1_2017Q3.csv.zip
# ./data_final/LoanStats_securev1_2016Q3.csv.zip
# records count for file  ./data_final/LoanStats_securev1_2016Q3.csv.zip  =  99122
# able to read  %s  zip file ./data_final/LoanStats_securev1_2016Q3.csv.zip
# ./data_final/LoanStats_securev1_2020Q1.csv.zip
# records count for file  ./data_final/LoanStats_securev1_2020Q1.csv.zip  =  105014
# able to read  %s  zip file ./data_final/LoanStats_securev1_2020Q1.csv.zip
# ./data_final/LoanStats_securev1_2019Q2.csv.zip
# records count for file  ./data_final/LoanStats_securev1_2019Q2.csv.zip  =  131006
# able to read  %s  zip file ./data_final/LoanStats_securev1_2019Q2.csv.zip
# ./data_final/LoanStats_securev1_2016Q1.csv.zip
# records count for file  ./data_final/LoanStats_securev1_2016Q1.csv.zip  =  133889
# able to read  %s  zip file ./data_final/LoanStats_securev1_2016Q1.csv.zip
# ./data_final/LoanStats_securev1_2019Q1.csv.zip
# records count for file  ./data_final/LoanStats_securev1_2019Q1.csv.zip  =  115575
# able to read  %s  zip file ./data_final/LoanStats_securev1_2019Q1.csv.zip
# ./data_final/LoanStats_securev1_2016Q4.csv.zip
# records count for file  ./data_final/LoanStats_securev1_2016Q4.csv.zip  =  103548
# able to read  %s  zip file ./data_final/LoanStats_securev1_2016Q4.csv.zip
# ./data_final/LoanStats_securev1_2019Q4.csv.zip
# records count for file  ./data_final/LoanStats_securev1_2019Q4.csv.zip  =  128260
# able to read  %s  zip file ./data_final/LoanStats_securev1_2019Q4.csv.zip
# ./data_final/LoanStats_securev1_2017Q2.csv.zip
# records count for file  ./data_final/LoanStats_securev1_2017Q2.csv.zip  =  105453
# able to read  %s  zip file ./data_final/LoanStats_securev1_2017Q2.csv.zip
# ./data_final/LoanStats_securev1_2019Q3.csv.zip
# records count for file  ./data_final/LoanStats_securev1_2019Q3.csv.zip  =  143037
# able to read  %s  zip file ./data_final/LoanStats_securev1_2019Q3.csv.zip
# ./data_final/LoanStats_securev1_2016Q2.csv.zip
# records count for file  ./data_final/LoanStats_securev1_2016Q2.csv.zip  =  97856
# able to read  %s  zip file ./data_final/LoanStats_securev1_2016Q2.csv.zip
# ./data_final/LoanStats_securev1_2018Q2.csv.zip
# records count for file  ./data_final/LoanStats_securev1_2018Q2.csv.zip  =  130774
# able to read  %s  zip file ./data_final/LoanStats_securev1_2018Q2.csv.zip
# ./data_final/LoanStats_securev1_2017Q1.csv.zip
# records count for file  ./data_final/LoanStats_securev1_2017Q1.csv.zip  =  96781
# able to read  %s  zip file ./data_final/LoanStats_securev1_2017Q1.csv.zip
# ./data_final/LoanStats_securev1_2018Q1.csv.zip
# records count for file  ./data_final/LoanStats_securev1_2018Q1.csv.zip  =  107866
# able to read  %s  zip file ./data_final/LoanStats_securev1_2018Q1.csv.zip
# ./data_final/LoanStats_securev1_2018Q3.csv.zip
# records count for file  ./data_final/LoanStats_securev1_2018Q3.csv.zip  =  128196
# able to read  %s  zip file ./data_final/LoanStats_securev1_2018Q3.csv.zip
# Reading, Extracting input zip files done...

# %%
print("total_records in input raw data frame",big_frame['id'].count())
big_frame.head()
# Out:
# total_records in input raw data frame 115575
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  148406308        NaN    12000.0      12000.0          12000.0   60 months
# 1  148501522        NaN    30000.0      30000.0          30000.0   60 months
# 2  149437986        NaN     2800.0       2800.0           2775.0   36 months
# 3  149444032        NaN    20000.0      20000.0          20000.0   60 months
# 4  149497729        NaN    25000.0      25000.0          25000.0   36 months
#
#   int_rate  installment grade sub_grade       ...         \
# 0   16.40%       294.38     C        C4       ...
# 1   20.00%       794.82     D        D2       ...
# 2    8.19%        87.99     A        A4       ...
# 3   22.50%       558.08     D        D3       ...
# 4    7.56%       778.35     A        A3       ...
#
#   orig_projected_additional_accrued_interest hardship_payoff_balance_amount  \
# 0                                        NaN                            NaN
# 1                                        NaN                            NaN
# 2                                        NaN                            NaN
# 3                                        NaN                            NaN
# 4                                        NaN                            NaN
#
#   hardship_last_payment_amount  debt_settlement_flag  \
# 0                          NaN                     N
# 1                          NaN                     N
# 2                          NaN                     N
# 3                          NaN                     N
# 4                          NaN                     N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#   settlement_amount settlement_percentage  settlement_term
# 0               NaN                   NaN              NaN
# 1               NaN                   NaN              NaN
# 2               NaN                   NaN              NaN
# 3               NaN                   NaN              NaN
# 4               NaN                   NaN              NaN
#
# [5 rows x 150 columns]

# %%
input_data_stats = big_frame.describe()
input_data_stats.to_excel("input_data_stats.xlsx")

# %%
big_frame.iloc[0:2,17:19]
# Out:
#   pymnt_plan                                                url
# 0          n  https://lendingclub.com/browse/loanDetail.acti...
# 1          n  https://lendingclub.com/browse/loanDetail.acti...

# %%
big_frame.info()

loan_all = big_frame.copy(deep=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115575 entries, 0 to 115574
# Columns: 150 entries, id to settlement_term
# dtypes: float64(112), object(38)
# memory usage: 132.3+ MB

# %%
big_frame.count()
# Out:
# id                                            115575
# member_id                                          0
# loan_amnt                                     115573
# funded_amnt                                   115573
# funded_amnt_inv                               115573
# term                                          115573
# int_rate                                      115573
# installment                                   115573
# grade                                         115573
# sub_grade                                     115573
# emp_title                                      96071
# emp_length                                    104479
# home_ownership                                115573
# annual_inc                                    115573
# verification_status                           115573
# issue_d                                       115573
# loan_status                                   115573
# pymnt_plan                                    115573
# url                                           115573
# desc                                               0
# purpose                                       115573
# title                                         115573
# zip_code                                      115573
# addr_state                                    115573
# dti                                           115316
# delinq_2yrs                                   115573
# earliest_cr_line                              115573
# fico_range_low                                115573
# fico_range_high                               115573
# inq_last_6mths                                115573
#                                                ...
# sec_app_mort_acc                               16669
# sec_app_open_acc                               16669
# sec_app_revol_util                             16439
# sec_app_open_act_il                            16669
# sec_app_num_rev_accts                          16669
# sec_app_chargeoff_within_12_mths               16669
# sec_app_collections_12_mths_ex_med             16669
# sec_app_mths_since_last_major_derog             4900
# hardship_flag                                 115573
# hardship_type                                    150
# hardship_reason                                  150
# hardship_status                                  150
# deferral_term                                    150
# hardship_amount                                  150
# hardship_start_date                              150
# hardship_end_date                                150
# payment_plan_start_date                          150
# hardship_length                                  150
# hardship_dpd                                     150
# hardship_loan_status                             150
# orig_projected_additional_accrued_interest       136
# hardship_payoff_balance_amount                   150
# hardship_last_payment_amount                     150
# debt_settlement_flag                          115573
# debt_settlement_flag_date                        330
# settlement_status                                330
# settlement_date                                  330
# settlement_amount                                330
# settlement_percentage                            330
# settlement_term                                  330
# Length: 150, dtype: int64

# %%
#identify columns where data missing data percentage is more than 33%
#columns for missing data more than 33%
missingdata = [x for x in big_frame.count() < len(big_frame)*0.33]
#print(missingdata)
columns_missing_data = big_frame.columns[missingdata]
print(columns_missing_data)
# Out:
# Index(['member_id', 'desc', 'mths_since_last_record',
#        'mths_since_last_major_derog', 'annual_inc_joint', 'dti_joint',
#        'verification_status_joint', 'mths_since_recent_bc_dlq',
#        'mths_since_recent_revol_delinq', 'revol_bal_joint',
#        'sec_app_fico_range_low', 'sec_app_fico_range_high',
#        'sec_app_earliest_cr_line', 'sec_app_inq_last_6mths',
#        'sec_app_mort_acc', 'sec_app_open_acc', 'sec_app_revol_util',
#        'sec_app_open_act_il', 'sec_app_num_rev_accts',
#        'sec_app_chargeoff_within_12_mths',
#        'sec_app_collections_12_mths_ex_med',
#        'sec_app_mths_since_last_major_derog', 'hardship_type',
#        'hardship_reason', 'hardship_status', 'deferral_term',
#        'hardship_amount', 'hardship_start_date', 'hardship_end_date',
#        'payment_plan_start_date', 'hardship_length', 'hardship_dpd',
#        'hardship_loan_status', 'orig_projected_additional_accrued_interest',
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'debt_settlement_flag_date', 'settlement_status', 'settlement_date',
#        'settlement_amount', 'settlement_percentage', 'settlement_term'],
#       dtype='object')

# %%
#identify columns where data missing data percentage is more than 33%
#columns for missing data more than 33%
missing_values = [x for x in ((big_frame.isnull().sum()/len(big_frame) * 100) > 33)]
type(missing_values)
#print(missing_values)
missing_values_1 = [ x for x in missing_values]
#print(missing_values_1)
columns_missing_data = big_frame.columns[missing_values]
print(columns_missing_data)
# Out:
# Index(['member_id', 'desc', 'mths_since_last_delinq', 'mths_since_last_record',
#        'mths_since_last_major_derog', 'annual_inc_joint', 'dti_joint',
#        'verification_status_joint', 'mths_since_recent_bc_dlq',
#        'mths_since_recent_revol_delinq', 'revol_bal_joint',
#        'sec_app_fico_range_low', 'sec_app_fico_range_high',
#        'sec_app_earliest_cr_line', 'sec_app_inq_last_6mths',
#        'sec_app_mort_acc', 'sec_app_open_acc', 'sec_app_revol_util',
#        'sec_app_open_act_il', 'sec_app_num_rev_accts',
#        'sec_app_chargeoff_within_12_mths',
#        'sec_app_collections_12_mths_ex_med',
#        'sec_app_mths_since_last_major_derog', 'hardship_type',
#        'hardship_reason', 'hardship_status', 'deferral_term',
#        'hardship_amount', 'hardship_start_date', 'hardship_end_date',
#        'payment_plan_start_date', 'hardship_length', 'hardship_dpd',
#        'hardship_loan_status', 'orig_projected_additional_accrued_interest',
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'debt_settlement_flag_date', 'settlement_status', 'settlement_date',
#        'settlement_amount', 'settlement_percentage', 'settlement_term'],
#       dtype='object')

# %%
loan_all.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'orig_projected_additional_accrued_interest',
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'debt_settlement_flag', 'debt_settlement_flag_date',
#        'settlement_status', 'settlement_date', 'settlement_amount',
#        'settlement_percentage', 'settlement_term'],
#       dtype='object', length=150)

# %%
def resumetable(df):
    print(f"Dataset Shape: {df.shape}")
    total_records = big_frame['id'].count()
    summary = pd.DataFrame(df.dtypes,columns=['dtypes'])
    summary = summary.reset_index()
    summary['Name'] = summary['index']
    summary = summary[['Name','dtypes']]
    summary['Missing'] = df.isnull().sum().values  
    summary['Missing Percentage'] = df.isnull().sum().values/total_records * 100
    summary['Uniques'] = df.nunique().values
    #summary['Mean Value'] = df.mean().values
    #summary['Median Value'] = df.median().values
    #summary['First Value'] = df.loc[0].values
    #summary['Second Value'] = df.loc[1].values
    #summary['Third Value'] = df.loc[2].values
    #summary.round({'Mean Value':2})
    summary.round({'Missing Percentage':2})

    for name in summary['Name'].value_counts().index:
        summary.loc[summary['Name'] == name, 'Entropy'] = round(stats.entropy(df[name].value_counts(normalize=True), base=2),2) 

    return summary

# %%
#numerical and categorical columns
#categorical columns
categorical_columns = loan_all.select_dtypes(include='object').columns
print(categorical_columns)
print(type(categorical_columns))
print("categorical_columns count = ",categorical_columns.size)
#numerical columns
numerical_columns = loan_all.select_dtypes(include ='float64').columns
print(numerical_columns)
print("numerical_columns count = ",numerical_columns.size)
for x in categorical_columns:
    print (x)
# Out:
# Index(['id', 'term', 'int_rate', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'verification_status', 'issue_d',
#        'loan_status', 'pymnt_plan', 'url', 'purpose', 'title', 'zip_code',
#        'addr_state', 'earliest_cr_line', 'revol_util', 'initial_list_status',
#        'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d',
#        'application_type', 'verification_status_joint',
#        'sec_app_earliest_cr_line', 'hardship_flag', 'hardship_type',
#        'hardship_reason', 'hardship_status', 'hardship_start_date',
#        'hardship_end_date', 'payment_plan_start_date', 'hardship_loan_status',
#        'debt_settlement_flag', 'debt_settlement_flag_date',
#        'settlement_status', 'settlement_date'],
#       dtype='object')
# <class 'pandas.core.indexes.base.Index'>
# categorical_columns count =  38
# Index(['member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'installment', 'annual_inc', 'desc', 'dti', 'delinq_2yrs',
#        'fico_range_low',
#        ...
#        'deferral_term', 'hardship_amount', 'hardship_length', 'hardship_dpd',
#        'orig_projected_additional_accrued_interest',
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'settlement_amount', 'settlement_percentage', 'settlement_term'],
#       dtype='object', length=112)
# numerical_columns count =  112
# id
# term
# int_rate
# grade
# sub_grade
# emp_title
# emp_length
# home_ownership
# verification_status
# issue_d
# loan_status
# pymnt_plan
# url
# purpose
# title
# zip_code
# addr_state
# earliest_cr_line
# revol_util
# initial_list_status
# last_pymnt_d
# next_pymnt_d
# last_credit_pull_d
# application_type
# verification_status_joint
# sec_app_earliest_cr_line
# hardship_flag
# hardship_type
# hardship_reason
# hardship_status
# hardship_start_date
# hardship_end_date
# payment_plan_start_date
# hardship_loan_status
# debt_settlement_flag
# debt_settlement_flag_date
# settlement_status
# settlement_date

# %%
dataTypeDict = dict(loan_all.select_dtypes(include=['object']).dtypes)

print(dataTypeDict)
# Out:
# {'id': dtype('O'), 'term': dtype('O'), 'int_rate': dtype('O'), 'grade': dtype('O'), 'sub_grade': dtype('O'), 'emp_title': dtype('O'), 'emp_length': dtype('O'), 'home_ownership': dtype('O'), 'verification_status': dtype('O'), 'issue_d': dtype('O'), 'loan_status': dtype('O'), 'pymnt_plan': dtype('O'), 'url': dtype('O'), 'purpose': dtype('O'), 'title': dtype('O'), 'zip_code': dtype('O'), 'addr_state': dtype('O'), 'earliest_cr_line': dtype('O'), 'revol_util': dtype('O'), 'initial_list_status': dtype('O'), 'last_pymnt_d': dtype('O'), 'next_pymnt_d': dtype('O'), 'last_credit_pull_d': dtype('O'), 'application_type': dtype('O'), 'verification_status_joint': dtype('O'), 'sec_app_earliest_cr_line': dtype('O'), 'hardship_flag': dtype('O'), 'hardship_type': dtype('O'), 'hardship_reason': dtype('O'), 'hardship_status': dtype('O'), 'hardship_start_date': dtype('O'), 'hardship_end_date': dtype('O'), 'payment_plan_start_date': dtype('O'), 'hardship_loan_status': dtype('O'), 'debt_settlement_flag': dtype('O'), 'debt_settlement_flag_date': dtype('O'), 'settlement_status': dtype('O'), 'settlement_date': dtype('O')}

# %%
#summary_columns_stats = resumetable(loan_all[:])[:60]
summary_columns_stats = resumetable(loan_all[:])
# Out:
# Dataset Shape: (115575, 150)

# %%
summary_columns_stats
# Out:
#                                            Name   dtypes  Missing  \
# 0                                            id   object        0
# 1                                     member_id  float64   115575
# 2                                     loan_amnt  float64        2
# 3                                   funded_amnt  float64        2
# 4                               funded_amnt_inv  float64        2
# 5                                          term   object        2
# 6                                      int_rate   object        2
# 7                                   installment  float64        2
# 8                                         grade   object        2
# 9                                     sub_grade   object        2
# 10                                    emp_title   object    19504
# 11                                   emp_length   object    11096
# 12                               home_ownership   object        2
# 13                                   annual_inc  float64        2
# 14                          verification_status   object        2
# 15                                      issue_d   object        2
# 16                                  loan_status   object        2
# 17                                   pymnt_plan   object        2
# 18                                          url   object        2
# 19                                         desc  float64   115575
# 20                                      purpose   object        2
# 21                                        title   object        2
# 22                                     zip_code   object        2
# 23                                   addr_state   object        2
# 24                                          dti  float64      259
# 25                                  delinq_2yrs  float64        2
# 26                             earliest_cr_line   object        2
# 27                               fico_range_low  float64        2
# 28                              fico_range_high  float64        2
# 29                               inq_last_6mths  float64        2
# ..                                          ...      ...      ...
# 120                            sec_app_mort_acc  float64    98906
# 121                            sec_app_open_acc  float64    98906
# 122                          sec_app_revol_util  float64    99136
# 123                         sec_app_open_act_il  float64    98906
# 124                       sec_app_num_rev_accts  float64    98906
# 125            sec_app_chargeoff_within_12_mths  float64    98906
# 126          sec_app_collections_12_mths_ex_med  float64    98906
# 127         sec_app_mths_since_last_major_derog  float64   110675
# 128                               hardship_flag   object        2
# 129                               hardship_type   object   115425
# 130                             hardship_reason   object   115425
# 131                             hardship_status   object   115425
# 132                               deferral_term  float64   115425
# 133                             hardship_amount  float64   115425
# 134                         hardship_start_date   object   115425
# 135                           hardship_end_date   object   115425
# 136                     payment_plan_start_date   object   115425
# 137                             hardship_length  float64   115425
# 138                                hardship_dpd  float64   115425
# 139                        hardship_loan_status   object   115425
# 140  orig_projected_additional_accrued_interest  float64   115439
# 141              hardship_payoff_balance_amount  float64   115425
# 142                hardship_last_payment_amount  float64   115425
# 143                        debt_settlement_flag   object        2
# 144                   debt_settlement_flag_date   object   115245
# 145                           settlement_status   object   115245
# 146                             settlement_date   object   115245
# 147                           settlement_amount  float64   115245
# 148                       settlement_percentage  float64   115245
# 149                             settlement_term  float64   115245
#
#      Missing Percentage  Uniques  Entropy
# 0              0.000000   115575    16.82
# 1            100.000000        0     0.00
# 2              0.001730     1499     6.05
# 3              0.001730     1499     6.05
# 4              0.001730     1525     6.25
# 5              0.001730        2     0.91
# 6              0.001730       53     4.89
# 7              0.001730    11793    11.15
# 8              0.001730        7     2.07
# 9              0.001730       33     4.34
# 10            16.875622    39356    13.11
# 11             9.600692       11     3.03
# 12             0.001730        5     1.44
# 13             0.001730     9817     8.11
# 14             0.001730        3     1.46
# 15             0.001730        3     1.58
# 16             0.001730        7     1.05
# 17             0.001730        2     0.01
# 18             0.001730   115573    16.82
# 19           100.000000        0     0.00
# 20             0.001730       12     1.88
# 21             0.001730       12     1.88
# 22             0.001730      877     8.93
# 23             0.001730       50     4.88
# 24             0.224097     6534    11.93
# 25             0.001730       20     0.80
# 26             0.001730      652     8.42
# 27             0.001730       38     4.64
# 28             0.001730       38     4.64
# 29             0.001730        6     1.28
# ..                  ...      ...      ...
# 120           85.577331       15     2.50
# 121           85.577331       56     4.63
# 122           85.776336     1066     9.85
# 123           85.577331       32     3.17
# 124           85.577331       69     4.86
# 125           85.577331       10     0.16
# 126           85.577331       10     0.29
# 127           95.760329      118     6.41
# 128            0.001730        2     0.01
# 129           99.870214        1     0.00
# 130           99.870214        9     2.51
# 131           99.870214        3     0.92
# 132           99.870214        1     0.00
# 133           99.870214      148     7.20
# 134           99.870214        6     2.07
# 135           99.870214        7     2.23
# 136           99.870214        7     2.13
# 137           99.870214        1     0.00
# 138           99.870214       27     4.61
# 139           99.870214        4     1.67
# 140           99.882327      134     7.06
# 141           99.870214      150     7.23
# 142           99.870214      149     7.22
# 143            0.001730        2     0.03
# 144           99.714471        9     2.52
# 145           99.714471        3     0.62
# 146           99.714471        9     2.65
# 147           99.714471      327     8.35
# 148           99.714471       74     4.19
# 149           99.714471       18     2.38
#
# [150 rows x 6 columns]

# %%
summary_columns_stats.to_excel("summary_columns_stats.xlsx")

# %%
#univariate analysis for outlier detection
sns.boxplot(x=loan_all['annual_inc'])

# %%
#identify columns where data missing data percentage is more than 33%
#outliers for annual_inc, those records are outliers which annual income is more that a million dollar i.e. 1e+06
loan_all[loan_all.annual_inc>1e+06]['annual_inc'].count()
#columns for missing data more than 33%
missingdata = [x for x in loan_all.count() < len(loan_all)*0.33]
#print(missingdata)
columns_missing_data = loan_all.columns[missingdata]
print(columns_missing_data)
# Out:
# Index(['member_id', 'desc', 'mths_since_last_record',
#        'mths_since_last_major_derog', 'annual_inc_joint', 'dti_joint',
#        'verification_status_joint', 'mths_since_recent_bc_dlq',
#        'mths_since_recent_revol_delinq', 'revol_bal_joint',
#        'sec_app_fico_range_low', 'sec_app_fico_range_high',
#        'sec_app_earliest_cr_line', 'sec_app_inq_last_6mths',
#        'sec_app_mort_acc', 'sec_app_open_acc', 'sec_app_revol_util',
#        'sec_app_open_act_il', 'sec_app_num_rev_accts',
#        'sec_app_chargeoff_within_12_mths',
#        'sec_app_collections_12_mths_ex_med',
#        'sec_app_mths_since_last_major_derog', 'hardship_type',
#        'hardship_reason', 'hardship_status', 'deferral_term',
#        'hardship_amount', 'hardship_start_date', 'hardship_end_date',
#        'payment_plan_start_date', 'hardship_length', 'hardship_dpd',
#        'hardship_loan_status', 'orig_projected_additional_accrued_interest',
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'debt_settlement_flag_date', 'settlement_status', 'settlement_date',
#        'settlement_amount', 'settlement_percentage', 'settlement_term'],
#       dtype='object')

# %%
print(len(loan_all.columns))
# Out:
# 150

# %%
#identify columns where data missing data percentage is more than 20%
#outliers for annual_inc, those records are outliers which annual income is more that a million dollar i.e. 1e+06
loan_all[loan_all.annual_inc>1e+06]['annual_inc'].count()
#columns for missing data more than 33%
missingdata = [x for x in loan_all.count() < len(loan_all)*0.20]
#print(missingdata)
columns_missing_data = loan_all.columns[missingdata]
print(columns_missing_data)
# Out:
# Index(['member_id', 'desc', 'mths_since_last_record', 'annual_inc_joint',
#        'dti_joint', 'verification_status_joint', 'mths_since_recent_bc_dlq',
#        'revol_bal_joint', 'sec_app_fico_range_low', 'sec_app_fico_range_high',
#        'sec_app_earliest_cr_line', 'sec_app_inq_last_6mths',
#        'sec_app_mort_acc', 'sec_app_open_acc', 'sec_app_revol_util',
#        'sec_app_open_act_il', 'sec_app_num_rev_accts',
#        'sec_app_chargeoff_within_12_mths',
#        'sec_app_collections_12_mths_ex_med',
#        'sec_app_mths_since_last_major_derog', 'hardship_type',
#        'hardship_reason', 'hardship_status', 'deferral_term',
#        'hardship_amount', 'hardship_start_date', 'hardship_end_date',
#        'payment_plan_start_date', 'hardship_length', 'hardship_dpd',
#        'hardship_loan_status', 'orig_projected_additional_accrued_interest',
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'debt_settlement_flag_date', 'settlement_status', 'settlement_date',
#        'settlement_amount', 'settlement_percentage', 'settlement_term'],
#       dtype='object')

# %%
#PreProcessing

#It appears there are a lot of NaNs. Few cols with 100% NAs- id, member_id, url; zip_code info is masked
loan_all.drop(['id', 'member_id', 'url', 'zip_code' ,'title' ], axis=1, inplace=True)

#also dropping cols with < 1/3 data
missingdata = [x for x in loan_all.count() < len(loan_all)*0.33]
loan_all.drop(loan_all.columns[missingdata], axis=1, inplace=True)
loan_all.shape
loan_all.columns

unique = loan_all.nunique()
unique = unique[unique.values == 1]
loan_all.drop(labels = list(unique.index), axis =1, inplace=True)
missingdata = [x for x in loan_all.count() < len(loan_all)*0.33]
loan_all.drop(loan_all.columns[missingdata], axis=1, inplace=True)
loan_all.shape
loan_all.columns

loan_all['annual_inc']= loan_all['annual_inc'].astype(float)
loan_all['annual_inc'].describe()
#len(loan_all[loan_all['annual_inc']>1e+06]) #251 appear to be outliers
loan=loan_all.drop(loan_all[loan_all.annual_inc>1e+06].index)

#data cleaning- bucketing, drop NAs
loan['revol_util'].isnull().sum() #856 NAs
loan[loan['revol_util'].isnull()]['loan_status'].value_counts() #mostly current loans
loan.dropna(subset=['revol_util'],inplace=True)
loan['revol_util'].isna().sum()

#buckets
loan['int_rate']=loan['int_rate'].astype(str)
loan['int_rate']= loan['int_rate'].map(lambda x: x.rstrip('%'))
loan['int_rate']= loan['int_rate'].astype(float)
loan['int_rate'].describe() # 5-30.9
# Out:
# count    115385.000000
# mean         12.715300
# std           4.853435
# min           6.000000
# 25%           8.190000
# 50%          11.800000
# 75%          15.570000
# max          30.890000
# Name: int_rate, dtype: float64

# %%
print(len(loan.columns))
# Out:
# 99

# %%
#1. selecting features based on correlation
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
label_encoder = LabelEncoder()
X_temp= loan[loan.columns.difference(['loan_status'])] #except label
y_temp = loan['loan_status']

#encode the categorial or string variables to number using encoding 
selected_columns =X_temp.columns
categorical_columns = X_temp.select_dtypes(include='object').columns
for x in categorical_columns:
    X_temp[x] = label_encoder.fit_transform(X_temp[x].astype(str)).astype('float64')
# Out:
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
sns.set(rc={'figure.figsize':(14,10)})
loan_cols_corr = X_temp.corr()
sns.heatmap(loan_cols_corr)

# %%
print(len(X_temp.columns))
print(loan_cols_corr.shape[0])
# Out:
# 98
# 98

# %%
#Next, we compare the correlation between features  and identify highly correlated variables 
#and remove one of two features that have a correlation higher than 0.8
cols = np.full((loan_cols_corr.shape[0],), True, dtype=bool)
cols_1 = []
for i in range(loan_cols_corr.shape[0]):
    for j in range(i+1, loan_cols_corr.shape[0]):
        if loan_cols_corr.iloc[i,j] >= 0.8:
            cols_1.append("(''" + loan_cols_corr.index[i] + "'' is highly correlated to ''" + loan_cols_corr.columns[j]+ "'')")
            if cols[j]:
                cols[j] = False
#insignificant_columns = X_temp.columns[cols]
#print(insignificant_columns)
print(len(X_temp.columns))
print(len(cols))
cols_1
# Out:
# 98
# 98
# ["(''acc_open_past_24mths'' is highly correlated to ''open_rv_24m'')",
#  "(''avg_cur_bal'' is highly correlated to ''tot_cur_bal'')",
#  "(''bc_open_to_buy'' is highly correlated to ''total_bc_limit'')",
#  "(''bc_util'' is highly correlated to ''percent_bc_gt_75'')",
#  "(''collection_recovery_fee'' is highly correlated to ''recoveries'')",
#  "(''fico_range_high'' is highly correlated to ''fico_range_low'')",
#  "(''funded_amnt'' is highly correlated to ''funded_amnt_inv'')",
#  "(''funded_amnt'' is highly correlated to ''installment'')",
#  "(''funded_amnt'' is highly correlated to ''loan_amnt'')",
#  "(''funded_amnt_inv'' is highly correlated to ''installment'')",
#  "(''funded_amnt_inv'' is highly correlated to ''loan_amnt'')",
#  "(''grade'' is highly correlated to ''int_rate'')",
#  "(''grade'' is highly correlated to ''sub_grade'')",
#  "(''hardship_flag'' is highly correlated to ''pymnt_plan'')",
#  "(''installment'' is highly correlated to ''loan_amnt'')",
#  "(''int_rate'' is highly correlated to ''sub_grade'')",
#  "(''last_fico_range_high'' is highly correlated to ''last_fico_range_low'')",
#  "(''last_pymnt_amnt'' is highly correlated to ''total_rec_prncp'')",
#  "(''num_actv_bc_tl'' is highly correlated to ''num_actv_rev_tl'')",
#  "(''num_actv_bc_tl'' is highly correlated to ''num_bc_sats'')",
#  "(''num_actv_bc_tl'' is highly correlated to ''num_rev_tl_bal_gt_0'')",
#  "(''num_actv_rev_tl'' is highly correlated to ''num_op_rev_tl'')",
#  "(''num_actv_rev_tl'' is highly correlated to ''num_rev_tl_bal_gt_0'')",
#  "(''num_bc_sats'' is highly correlated to ''num_bc_tl'')",
#  "(''num_bc_sats'' is highly correlated to ''num_op_rev_tl'')",
#  "(''num_bc_tl'' is highly correlated to ''num_rev_accts'')",
#  "(''num_op_rev_tl'' is highly correlated to ''num_rev_accts'')",
#  "(''num_op_rev_tl'' is highly correlated to ''num_rev_tl_bal_gt_0'')",
#  "(''num_op_rev_tl'' is highly correlated to ''num_sats'')",
#  "(''num_op_rev_tl'' is highly correlated to ''open_acc'')",
#  "(''num_sats'' is highly correlated to ''open_acc'')",
#  "(''num_tl_op_past_12m'' is highly correlated to ''open_rv_12m'')",
#  "(''out_prncp'' is highly correlated to ''out_prncp_inv'')",
#  "(''pub_rec'' is highly correlated to ''pub_rec_bankruptcies'')",
#  "(''tot_cur_bal'' is highly correlated to ''tot_hi_cred_lim'')",
#  "(''total_bal_ex_mort'' is highly correlated to ''total_bal_il'')",
#  "(''total_bal_ex_mort'' is highly correlated to ''total_il_high_credit_limit'')",
#  "(''total_bal_il'' is highly correlated to ''total_il_high_credit_limit'')",
#  "(''total_bc_limit'' is highly correlated to ''total_rev_hi_lim'')",
#  "(''total_pymnt'' is highly correlated to ''total_pymnt_inv'')",
#  "(''total_pymnt'' is highly correlated to ''total_rec_prncp'')",
#  "(''total_pymnt_inv'' is highly correlated to ''total_rec_prncp'')"]

# %%
#remove one of two features that have a correlation higher than 0.9
columns = np.full((loan_cols_corr.shape[0],), True, dtype=bool)
insig_columns = np.full((loan_cols_corr.shape[0],), False, dtype=bool)
for i in range(loan_cols_corr.shape[0]):
    for j in range(i+1, loan_cols_corr.shape[0]):
        if loan_cols_corr.iloc[i,j] >= 0.8:
            if columns[j]:
                columns[j] = False
                insig_columns[j] = True
selected_columns = X_temp.columns[columns]
not_selected_columns = X_temp.columns[insig_columns]
X_temp_new = X_temp[selected_columns]

# %%
print(len(X_temp_new.columns))
# Out:
# 68

# %%
for x in not_selected_columns:
    print(x)
# Out:
# fico_range_low
# funded_amnt_inv
# installment
# int_rate
# last_fico_range_low
# loan_amnt
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# open_acc
# open_rv_12m
# open_rv_24m
# out_prncp_inv
# percent_bc_gt_75
# pub_rec_bankruptcies
# pymnt_plan
# recoveries
# sub_grade
# tot_cur_bal
# tot_hi_cred_lim
# total_bal_il
# total_bc_limit
# total_il_high_credit_limit
# total_pymnt_inv
# total_rec_prncp
# total_rev_hi_lim

# %%
# derived variables as part of preprocessing
buck = [0, 5, 10, 15, 20,25, 35]
lab = ['0-5', '5-10', '10-15', '15-20', '20-25','>25']
loan['int_rate_range'] = pd.cut(loan['int_rate'], buck, labels=lab)

loan['loan_amnt'].describe() #0-40k
buck = [0, 5000, 10000, 15000, 20000, 25000,40000]
lab = ['0-5000', '5000-10000', '10000-15000', '15000-20000', '20000-25000','25000 and above']
loan['loan_amnt_range'] = pd.cut(loan['loan_amnt'], buck, labels=lab)

loan['annual_inc'].describe() #range 1 to 1 mill
buck = [0, 25000, 50000, 75000, 100000,1000000]
lab = ['0-25000', '25000-50000', '50000-75000', '75000-100000', '100000 and above']
loan['annual_inc_range'] = pd.cut(loan['annual_inc'], buck, labels=lab)

# %%
#total records after preprocessing
total = len(loan)
print('total records after preprocessing',total)
# Out:
# total records after preprocessing 115385

# %%
print(loan['int_rate_range'].value_counts())
# Out:
# 10-15    44758
# 5-10     37025
# 15-20    25841
# 20-25     5351
# >25       2410
# 0-5          0
# Name: int_rate_range, dtype: int64

# %%
print(loan['loan_amnt_range'].value_counts())
# Out:
# 5000-10000         28850
# 25000 and above    22157
# 10000-15000        21118
# 15000-20000        18284
# 0-5000             13890
# 20000-25000        11086
# Name: loan_amnt_range, dtype: int64

# %%
loan['annual_inc_range'].value_counts()
# Out:
# 50000-75000         32544
# 100000 and above    27918
# 25000-50000         27745
# 75000-100000        22123
# 0-25000              4801
# Name: annual_inc_range, dtype: int64

# %%
#distribution of loan amount and interest rate
tmp = loan[["loan_amnt", "int_rate"]]
#loanDF.printSchema()

fig, ax =plt.subplots(2,2, figsize=(18,12))
plt.subplots_adjust(hspace = 0.4, top = 0.8)

# Loan amount distribution plots
sns.distplot(tmp.loan_amnt, fit=stats.gamma, axlabel="Loan Amount", label="Loan Amount Frequency distribution", ax=ax[0][0])
sns.boxplot(x=tmp.loan_amnt, ax=ax[0][1])

# Interest rates distribution plots
sns.distplot(tmp.int_rate, fit=stats.gamma, axlabel="Interest Rate", label="Interest Frequency distribution", ax=ax[1][0])
sns.boxplot(x=tmp.int_rate, ax=ax[1][1])

fig.show()
fig.savefig("fig_loan_amount_and_interest_rate_distribution.png")
# Out:
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
#distribution of annual income
loan_annual_inc_plot = loan_all.loc[(loan_all['annual_inc'] < 0.1e+7)]
#univariate analysis for outlier detection
#sns.boxplot(x=loan_all['annual_inc'])
sns.set(rc={'figure.figsize':(20,5.27)})
fig, ax =plt.subplots(1,2)

plot1 = sns.boxplot(x=loan_all['annual_inc'],ax=ax[0])
plot1.set_title("Annual Income Box Plot before removing high value", fontsize=20)
plot2 = sns.boxplot(x=loan_annual_inc_plot['annual_inc'],ax=ax[1])
plot2.set_title("Annual Income Box Plot after removing high value", fontsize=20)
fig.savefig("fig_annual_income_box_plot.png")

# %%
#Distribution of annual income 
total = len(loan['annual_inc_range'])
import math
#I will start looking the loan_amnt column
sns.set(rc={'figure.figsize':(10,5.27)})
fig, ax =plt.subplots(2,1)
#fig, g = plt.subplots(figsize=(10,7))
plt.subplots_adjust(hspace = 0.4, top = 0.8)

# Loan Amt frequency plot

g = sns.distplot(loan_annual_inc_plot['annual_inc'], 
                 fit=stats.gamma, axlabel="Annual Income", label="Annual Income Frequency distribution",ax=ax[0])
g.set_xlabel("Annual Income", fontsize=16)
g.set_ylabel("Frequency", fontsize=16)
g.set_title("Annual Income Distribuition", fontsize=20)


## Interest plot
plt.subplots_adjust(top=1)
g1 = sns.countplot(x="annual_inc_range", data=loan, 
                  color='blue',ax=ax[1])
g1.set_xlabel("Annual Income", fontsize=16)
g1.set_ylabel("Count", fontsize=16)
g1.set_title("Annual Income Range plot", fontsize=20)

for p in g1.patches:
        x = float(p.get_height())
        if (math.isnan(x)):
            height = 0
        else:
            height = p.get_height()
        
        g1.annotate('%{:.1f}'.format(height/total*100), (p.get_x()+0.1, height+50))
plt.show()
#g1_fig = g1.get_figure()
#fig.savefig("Loan Amount And Interest Rate Distribuition.png")
fig.savefig("fig_annual_income_distribution.png")
# Out:
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
loan_annual_inc_plot['annual_inc'].describe()
# Out:
# count    115511.000000
# mean      83354.784205
# std       58091.094821
# min           0.000000
# 25%       49000.000000
# 50%       70000.000000
# 75%      100000.000000
# max      999400.000000
# Name: annual_inc, dtype: float64

# %%
#loan amount plotting
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(loan['loan_amnt'])
# Out:
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#interest rate frequency plot
sns.distplot(loan['int_rate'])
# Out:
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
loan['int_rate_range'].head()
#print(np.any(np.isnan(X)))
# Out:
# 0    15-20
# 1    15-20
# 2     5-10
# 3    20-25
# 4     5-10
# Name: int_rate_range, dtype: category
# Categories (6, object): [0-5 < 5-10 < 10-15 < 15-20 < 20-25 < >25]

# %%
#LOAN AMOUNT and INTEREST RATE Distributions
total = len(loan)
import math
#I will start looking the loan_amnt column
sns.set(rc={'figure.figsize':(10,5.27)})
fig, ax =plt.subplots(2,1)
#fig, g = plt.subplots(figsize=(10,7))
plt.subplots_adjust(hspace = 0.4, top = 0.8)

# Loan Amt frequency plot

g = sns.distplot(loan["loan_amnt"],ax=ax[0])
g.set_xlabel("Loan Amount Value", fontsize=16)
g.set_ylabel("Frequency", fontsize=16)
g.set_title("Loan Amount Distribuition", fontsize=20)


## Interest plot
plt.subplots_adjust(top=1)
g1 = sns.countplot(x="int_rate_range", data=loan, 
                  color='blue',ax=ax[1])
g1.set_xlabel("Loan Interest Rate", fontsize=16)
g1.set_ylabel("Count", fontsize=16)
g1.set_title("Interest Rate Distribuition", fontsize=20)

for p in g1.patches:
        x = float(p.get_height())
        if (math.isnan(x)):
            height = 0
        else:
            height = p.get_height()
        
        g1.annotate('%{:.1f}'.format(height/total*100), (p.get_x()+0.1, height+50))
plt.show()
#g1_fig = g1.get_figure()
#fig.savefig("Loan Amount And Interest Rate Distribuition.png")
fig.savefig("fig_loan_and_interest_dist.png")
# Out:
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#univariate analysis for outlier detection
#sns.boxplot(x=loan_all['annual_inc'])
loan_annual_inc_plot = loan_all.loc[(loan_all['annual_inc'] < 0.1e+7)]
sns.set(rc={'figure.figsize':(20,5.27)})
fig, ax =plt.subplots(1,2)

plot1 = sns.boxplot(x=loan_all['annual_inc'],ax=ax[0])
plot1.set_title("Annual Income Box Plot before removing high value", fontsize=20)
plot2 = sns.boxplot(x=loan_annual_inc_plot['annual_inc'],ax=ax[1])
plot2.set_title("Annual Income Box Plot after removing high value", fontsize=20)
# Out:
# Text(0.5,1,'Annual Income Box Plot after removing high value')

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(loan['annual_inc'])
# Out:
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#distribution of loan status
sns.set(rc={'figure.figsize':(14.7,8.27)})
g1 = sns.countplot(loan['loan_status'])
g1.set_xlabel("Loan Status", fontsize=16)
g1.set_ylabel("Count", fontsize=16)
g1.set_title("Loan Status Distribuition", fontsize=20)
for p in g1.patches:
        x = float(p.get_height())
        if (math.isnan(x)):
            height = 0
        else:
            height = p.get_height()
        #g1.annotate(height, (p.get_x()+0.1, height+50))
        g1.annotate('%{:.1f}'.format(height/total*100), (p.get_x()+0.1, height+50))
        
plt.show()   
g1_fig = g1.get_figure()
g1_fig.savefig("fig_distribution_of_loan_status.png")
loan['loan_status'].value_counts()
# Out:
# Current               91008
# Fully Paid            16828
# Charged Off            3865
# Late (31-120 days)     1846
# In Grace Period        1404
# Late (16-30 days)       360
# Default                  74
# Name: loan_status, dtype: int64

# %%
#derived variable 'good_loan'
#distribution of derived variable 'good_loan'
#good loans- Fully paid, current and bad loans- charged off,default, late, in grace period 
#deleting issued loans from data

loan['loan_status'].value_counts()/len(loan)
loan.drop(loan[loan.loan_status== 'Issued'].index, inplace=True)
loan['good_loan'] = np.where((loan.loan_status == 'Fully Paid') |
                        (loan.loan_status == 'Current'), 1, 0)
loan['good_loan'].value_counts()/len(loan)
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns_plot_good_vs_bad_loan = sns.countplot(loan['good_loan'])
fig_good_vs_bad_loan = sns_plot_good_vs_bad_loan.get_figure()
fig_good_vs_bad_loan.savefig("fig_good_vs_bad_loan.png")

# %%
#most common loan grade
plt.subplots_adjust(top=1)
sns.set(rc={'figure.figsize':(8,5)})
g1 = sns.countplot(x="grade", data=loan)
g1.set_xlabel("Grade", fontsize=16)
g1.set_ylabel("Count", fontsize=16)
g1.set_title("Loan Grade Distribution ", fontsize=20)

height = len(loan['grade'])

for p in g1.patches:
        x = float(p.get_height())
        if (math.isnan(x)):
            height = 0
        else:
            height = p.get_height()
        
        g1.annotate('%{:.1f}'.format(height/total*100), (p.get_x()+0.1, height+50))
plt.show()
g1_fig = g1.get_figure()
g1_fig.savefig("fig_loan_grade_distribution.png")

# %%
loan['sub_grade'].unique()
# Out:
# array(['C4', 'D2', 'A4', 'D3', 'A3', 'C3', 'A5', 'C1', 'B4', 'B5', 'B2',
#        'C2', 'B3', 'D1', 'C5', 'A1', 'D5', 'A2', 'D4', 'B1', 'E5', 'G2',
#        'E1', 'E2', 'G1', 'E3', 'E4', 'F5', 'F1', 'F4', 'F2', 'F3', 'G3'],
#       dtype=object)

# %%
#most common loan sub grade
plt.subplots_adjust(top=1)
sns.set(rc={'figure.figsize':(15,7)})
g1 = sns.countplot(x="sub_grade", data=loan)
g1.set_xlabel("Sub Grade", fontsize=16)
g1.set_ylabel("Count", fontsize=16)
g1.set_title("Loan Sub Grade Distribution ", fontsize=20)

height = len(loan['sub_grade'])

for p in g1.patches:
        x = float(p.get_height())
        if (math.isnan(x)):
            height = 0
        else:
            height = p.get_height()
        
        g1.annotate('%{:.1f}'.format(height/total*100), (p.get_x()+0.1, height+50))
plt.show()
g1_fig = g1.get_figure()
g1_fig.savefig("fig_loan_sub_grade_distribution.png")

# %%
for x in loan.columns:
    print (x)
# Out:
# loan_amnt
# funded_amnt
# funded_amnt_inv
# term
# int_rate
# installment
# grade
# sub_grade
# emp_title
# emp_length
# home_ownership
# annual_inc
# verification_status
# issue_d
# loan_status
# pymnt_plan
# purpose
# addr_state
# dti
# delinq_2yrs
# earliest_cr_line
# fico_range_low
# fico_range_high
# inq_last_6mths
# mths_since_last_delinq
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# initial_list_status
# out_prncp
# out_prncp_inv
# total_pymnt
# total_pymnt_inv
# total_rec_prncp
# total_rec_int
# total_rec_late_fee
# recoveries
# collection_recovery_fee
# last_pymnt_d
# last_pymnt_amnt
# next_pymnt_d
# last_credit_pull_d
# last_fico_range_high
# last_fico_range_low
# collections_12_mths_ex_med
# application_type
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_act_il
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_inq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
# hardship_flag
# debt_settlement_flag
# int_rate_range
# loan_amnt_range
# annual_inc_range
# good_loan

# %%
loan['purpose'].unique()
# Out:
# array(['credit_card', 'other', 'debt_consolidation', 'home_improvement',
#        'car', 'small_business', 'medical', 'major_purchase', 'moving',
#        'house', 'vacation', 'renewable_energy'], dtype=object)

# %%
loan['application_type'].unique()
# Out:
# array(['Individual', 'Joint App'], dtype=object)

# %%
sns.set(rc={'figure.figsize':(20.7,12.27)})

sns.countplot(loan['purpose'],hue=loan['good_loan'])

# %%
sns.set(rc={'figure.figsize':(20.7,10.27)})
sns.countplot(loan['purpose'],hue=loan['loan_amnt_range'])

# %%
sns.set(rc={'figure.figsize':(20.7,10.27)})
sns.countplot(loan['purpose'],hue=loan['good_loan'])

# %%
sns.set(rc={'figure.figsize':(20.7,10.27)})
sns.countplot(loan['purpose'],hue=loan['loan_amnt_range'])

# %%
loan['home_ownership'].unique()
# Out:
# array(['MORTGAGE', 'RENT', 'OWN', 'ANY', 'NONE'], dtype=object)

# %%
#home ownership- any and none dont signify anything
sns.set(rc={'figure.figsize':(20.7,10.27)})
loan.drop(loan[loan['home_ownership']== 'ANY'].index, inplace=True)
loan.drop(loan[loan['home_ownership']== 'NONE'].index, inplace=True)
sns.countplot(loan['home_ownership'],hue=loan['good_loan'])

# %%
#employment length
sns.set(rc={'figure.figsize':(20.7,10.27)})
sns.countplot(loan['emp_length'],hue=loan['good_loan'])
sns.countplot(loan['emp_length'],hue=loan['loan_amnt_range'])

# %%
loan['addr_state'].unique()
# Out:
# array(['NC', 'TX', 'LA', 'IL', 'NJ', 'FL', 'AZ', 'OK', 'AR', 'IN', 'WI',
#        'NY', 'WY', 'TN', 'CA', 'MA', 'MO', 'MI', 'ND', 'NM', 'AL', 'GA',
#        'WA', 'OR', 'OH', 'MN', 'PA', 'MD', 'VA', 'KY', 'UT', 'ID', 'MT',
#        'CO', 'SC', 'NH', 'NV', 'CT', 'KS', 'HI', 'MS', 'AK', 'ME', 'DC',
#        'WV', 'DE', 'NE', 'SD', 'RI', 'VT'], dtype=object)

# %%
#geography
sns.set(rc={'figure.figsize':(20.7,10.27)})
sns.countplot(loan['addr_state'],hue=loan['good_loan'])

# %%
sns.countplot(loan['addr_state'],hue=loan['loan_amnt_range'])

# %%
#monthly trend
loan['issue_yr']=pd.DatetimeIndex(loan['issue_d']).year
loan['issue_mon']=pd.DatetimeIndex(loan['issue_d']).month
sns.countplot(loan['issue_mon'],hue=loan['good_loan'])

# %%
#understanding correlation between some key business variables
cor_loan=loan[['loan_amnt','annual_inc', 'good_loan', 'int_rate', 'dti', 
               'tot_cur_bal', 'funded_amnt']]
f, ax = plt.subplots(figsize=(14, 9))
sns.heatmap(cor_loan.corr(), 
            xticklabels=cor_loan.columns.values,
            yticklabels=cor_loan.columns.values,annot= True)
plt.show()

# %%
#numerical and categorical columns
#categorical columns
categorical_columns = loan.select_dtypes(include='object').columns
print(categorical_columns)
print(type(categorical_columns))
print("categorical_columns count = ",categorical_columns.size)
#numerical columns
numerical_columns = loan.select_dtypes(include ='float64').columns
print(numerical_columns)
print("numerical_columns count = ",numerical_columns.size)
for x in categorical_columns:
    print (x)
# Out:
# Index(['term', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        'home_ownership', 'verification_status', 'issue_d', 'loan_status',
#        'pymnt_plan', 'purpose', 'addr_state', 'earliest_cr_line', 'revol_util',
#        'initial_list_status', 'last_pymnt_d', 'next_pymnt_d',
#        'last_credit_pull_d', 'application_type', 'hardship_flag',
#        'debt_settlement_flag'],
#       dtype='object')
# <class 'pandas.core.indexes.base.Index'>
# categorical_columns count =  21
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'int_rate',
#        'installment', 'annual_inc', 'dti', 'delinq_2yrs', 'fico_range_low',
#        'fico_range_high', 'inq_last_6mths', 'mths_since_last_delinq',
#        'open_acc', 'pub_rec', 'revol_bal', 'total_acc', 'out_prncp',
#        'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp',
#        'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_amnt', 'last_fico_range_high',
#        'last_fico_range_low', 'collections_12_mths_ex_med', 'tot_coll_amt',
#        'tot_cur_bal', 'open_acc_6m', 'open_act_il', 'open_il_12m',
#        'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'il_util',
#        'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util',
#        'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m',
#        'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util',
#        'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct',
#        'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl',
#        'mort_acc', 'mths_since_recent_bc', 'mths_since_recent_inq',
#        'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl',
#        'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl',
#        'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats',
#        'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq',
#        'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tot_hi_cred_lim',
#        'total_bal_ex_mort', 'total_bc_limit', 'total_il_high_credit_limit'],
#       dtype='object')
# numerical_columns count =  78
# term
# grade
# sub_grade
# emp_title
# emp_length
# home_ownership
# verification_status
# issue_d
# loan_status
# pymnt_plan
# purpose
# addr_state
# earliest_cr_line
# revol_util
# initial_list_status
# last_pymnt_d
# next_pymnt_d
# last_credit_pull_d
# application_type
# hardship_flag
# debt_settlement_flag

# %%
#VARIABLE SELECTION ################################
#for classification purpose, we need to drop retrospective variables
loan.drop(['funded_amnt', 'funded_amnt_inv', 'total_pymnt', 
'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 
'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d', 
'recoveries', 'collection_recovery_fee'], axis=1, inplace=True)

#change variable type- encoding - 'earliest_cr_line' and emp_length

loan.head()

loan['emp_length'].value_counts()
emp_range= {'< 1 year':0.5, '1 year':1, '2 years': 2, '3 years':3,
            '4 years':4, '5 years':5,'6 years':6,'7 years':7,
            '8 years':8,'9 years':9, '10+ years':10}
loan['emplen'] = loan["emp_length"].map(emp_range)
loan['emplen'].isnull().sum() 
loan['emplen'].value_counts()
# Out:
# 10.0    34182
# 0.5     14896
# 2.0      9588
# 3.0      8623
# 1.0      7848
# 5.0      7129
# 4.0      6721
# 6.0      4588
# 7.0      3868
# 8.0      3598
# 9.0      2539
# Name: emplen, dtype: int64

# %%
loan.columns
# Out:
# Index(['loan_amnt', 'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        'emp_title', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'issue_d', 'loan_status', 'pymnt_plan',
#        'purpose', 'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'fico_range_low', 'fico_range_high', 'inq_last_6mths',
#        'mths_since_last_delinq', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_rec_late_fee', 'next_pymnt_d',
#        'last_fico_range_high', 'last_fico_range_low',
#        'collections_12_mths_ex_med', 'application_type', 'tot_coll_amt',
#        'tot_cur_bal', 'open_acc_6m', 'open_act_il', 'open_il_12m',
#        'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'il_util',
#        'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util',
#        'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m',
#        'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util',
#        'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct',
#        'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl',
#        'mort_acc', 'mths_since_recent_bc', 'mths_since_recent_inq',
#        'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl',
#        'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl',
#        'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats',
#        'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq',
#        'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tot_hi_cred_lim',
#        'total_bal_ex_mort', 'total_bc_limit', 'total_il_high_credit_limit',
#        'hardship_flag', 'debt_settlement_flag', 'int_rate_range',
#        'loan_amnt_range', 'annual_inc_range', 'good_loan', 'issue_yr',
#        'issue_mon', 'emplen'],
#       dtype='object')

# %%
############Missing Value- Imputation############
nullseries=pd.isnull(loan).sum()
nullseries[nullseries>0]

loan['emplen'] = loan['emplen'].replace(np.nan, 10)
#loan.drop(['emp_length'],axis=1,inplace=True)

loan['mths_since_last_delinq'] = loan['mths_since_last_delinq'].fillna(loan['mths_since_last_delinq'].median()) #mean and median v similar
#loan['mths_since_recent_revol_delinq']=loan['mths_since_recent_revol_delinq'].fillna(loan['mths_since_recent_revol_delinq'].median())
loan['percent_bc_gt_75'] = loan['percent_bc_gt_75'].fillna(loan['percent_bc_gt_75'].median()) #mean and median v similar

# %%
#very few missing values for all of them
loan['dti'] = loan['dti'].fillna(loan['dti'].mean())
loan['inq_last_6mths'] = loan['inq_last_6mths'].fillna(loan['inq_last_6mths'].mean())
loan['open_acc_6m'] = loan['open_acc_6m'].fillna(loan['open_acc_6m'].median())
loan['open_act_il'] = loan['open_act_il'].fillna(loan['open_act_il'].median())
loan['open_il_12m'] = loan['open_il_12m'].fillna(loan['open_il_12m'].median())
loan['open_il_24m'] = loan['open_il_24m'].fillna(loan['open_il_24m'].median())
loan['open_rv_12m'] = loan['open_rv_12m'].fillna(loan['open_rv_12m'].median())
loan['open_rv_24m'] = loan['open_rv_24m'].fillna(loan['open_rv_24m'].median())
loan['max_bal_bc'] = loan['max_bal_bc'].fillna(loan['max_bal_bc'].median())
loan['all_util'] = loan['all_util'].fillna(loan['all_util'].median())
loan['inq_fi'] = loan['inq_fi'].fillna(loan['inq_fi'].median())
loan['total_cu_tl'] = loan['total_cu_tl'].fillna(loan['total_cu_tl'].median())
loan['total_bal_il']=loan['total_bal_il'].fillna(loan['total_bal_il'].mean())

loan['inq_last_12m'] = loan['inq_last_12m'].fillna(loan['inq_last_12m'].median())
if set(['num_tl_120dpd_2m']).issubset(loan.columns):
    loan['num_tl_120dpd_2m'] = loan['num_tl_120dpd_2m'].fillna(loan['num_tl_120dpd_2m'].median())
loan['pct_tl_nvr_dlq'] = loan['pct_tl_nvr_dlq'].fillna(loan['pct_tl_nvr_dlq'].median())
#loan['hardship_flag'] = loan['hardship_flag'].fillna(0.0)

# %%
#loan['inq_last_12m'].notnull()

# %%
#A lot of NAs- with integer values so median replacement
loan['mths_since_rcnt_il']=loan['mths_since_rcnt_il'].fillna(loan['mths_since_rcnt_il'].median())
loan['il_util']=loan['il_util'].fillna(loan['il_util'].median())

# %%
loan['bc_open_to_buy'].value_counts() # 0s occur the most
loan['bc_open_to_buy']=loan['bc_open_to_buy'].fillna(0)

# %%
# bc_util= total current balance/credit limit
loan[loan['bc_util'].isnull()]['bc_open_to_buy'].value_counts() #mostly 0s
loan[loan['bc_open_to_buy']==0]['bc_util'].value_counts() #bcutil is~100
loan['bc_util']=loan['bc_util'].fillna(100)
loan['mo_sin_old_il_acct']=loan['il_util'].fillna(loan['il_util'].median()) #mostly around 120-130
loan['mths_since_recent_bc']=loan['mths_since_recent_bc'].fillna(loan['mths_since_recent_bc'].median()) #no corr found
loan['mths_since_recent_inq']=loan['mths_since_recent_inq'].fillna(loan['mths_since_recent_inq'].median()) #no corr found
#loan['num_tl_120dpd_2m']=loan['num_tl_120dpd_2m'].fillna(0) #0 common

# %%
#Feature Engineering- credit length
loan['earliest_crline_yr']=pd.DatetimeIndex(loan['earliest_cr_line']).year
loan['earliest_crline_mon'],loan['earliest_crline_yr'] = loan['earliest_cr_line'].str.split('-', 1).str

# %%
loan['issue_yr'].head()
# Out:
# 0    2019
# 1    2019
# 2    2019
# 3    2019
# 4    2019
# Name: issue_yr, dtype: int64

# %%
#loan['issue_yr'].apply(int)

# %%
loan.loc[loan['issue_yr'].apply(pd.to_numeric, args=('coerce',))> 18, 'issue_yr'] = '19' + loan['issue_yr'].astype(str)

# %%
#changing similarly for issue year as well- to capture the difference in years
if set(['issue_d','issue_mon']).issubset(loan.columns):
    loan['issue_yr'].apply(int)
    loan.loc[loan['issue_yr'].apply(pd.to_numeric, args=('coerce',))> 18, 'issue_yr'] = '19' + loan['issue_yr'].astype(str)
    loan.loc[loan['issue_yr'].apply(pd.to_numeric, args=('coerce',))< 19, 'issue_yr'] = '20' + loan['issue_yr'].astype(str)
    loan['issue_yr'].apply(int)
    loan.drop(['issue_d', 'issue_mon'], axis=1, inplace=True)

# %%
#now to introduce new variable for checking the difference of these 2 and drop them
if set(['issue_yr','earliest_crline_yr']).issubset(loan.columns):
    loan['credit_len']=loan['issue_yr'].apply(int)-loan['earliest_crline_yr'].apply(int)
    loan.drop(['issue_yr', 'earliest_crline_yr'],axis=1, inplace=True)

# %%
#Categorical variables- introducing levels/encoding where not ordinal 
#verification status,subgrade, purpose,addr_state

verification_map={'Source Verified':3, 'Verified':2, 'Not Verified':1}
loan['verification_status']=loan['verification_status'].map(verification_map)

ownership_map={'MORTGAGE':1, 'RENT':2, 'OWN':3}
loan['home_ownership']=loan['home_ownership'].map(ownership_map)

subgrade_map={'A1':1,'A2':2, 'A3':3, 'A4':4, 'A5':5, 'B1':6, 'B2':7, 'B3':8, 'B4':9, 'B5':10, 
              'C1':11, 'C2':12, 'C3':13, 'C4':14, 'C5':15, 'D1':16, 'D2':17, 'D3':18, 
              'D4':19, 'D5':20, 'E1':21, 'E2':22, 'E3':23, 'E4':24, 'E5':25, 'F1':26, 
              'F2':27, 'F3':28, 'F4':29, 'F5':30, 'G1':31, 'G2':32, 'G3':33, 'G4':34, 'G5':35}
loan['sub_grade']=loan['sub_grade'].map(subgrade_map)
if set(['grade']).issubset(loan.columns):
    loan.drop(['grade'],axis=1, inplace=True)

hardship_map={'N':0, 'Y':1}
loan['hardship_flag']=loan['hardship_flag'].map(hardship_map)

debtsett_map={'N':0, 'Y':1}
loan['debt_settlement_flag']=loan['debt_settlement_flag'].map(debtsett_map)

# %%
#purpose needs to be hot encoded- so better to drop unnecessary levels
if set(['purpose']).issubset(loan.columns):
    loan= loan[loan['purpose'] != 'educational']
    loan= loan[loan['purpose'] !='wedding']
    loan= loan[loan['purpose'] !='other']
    loan['loan_amnt'].isna().sum()
    loan.shape
    enc1= pd.get_dummies(loan['purpose'])
    loan=pd.concat((loan,enc1), axis=1)
    loan.drop(['purpose'],axis=1,inplace=True)

if set(['addr_state']).issubset(loan.columns):
    enc2= pd.get_dummies(loan['addr_state'])
    loan=pd.concat((loan,enc2), axis=1)
    loan.drop(['addr_state'],axis=1,inplace=True)

if set(['disbursement_method']).issubset(loan.columns):
    enc3= pd.get_dummies(loan['disbursement_method'])
    loan=pd.concat((loan,enc3), axis=1)
    loan.drop(['disbursement_method'],axis=1,inplace=True)
if set(['application_type']).issubset(loan.columns):
    enc4= pd.get_dummies(loan['application_type'])
    loan=pd.concat((loan,enc4), axis=1)
    loan.drop(['application_type'],axis=1,inplace=True)

# %%
#to delete
if set(['earliest_cr_line','loan_amnt_range', 'annual_inc_range',
           'int_rate_range','loan_status', 'next_pymnt_d','emp_title'
           ,'pymnt_plan','initial_list_status', 'total_rec_late_fee']).issubset(loan.columns):
    loan.drop(['earliest_cr_line','loan_amnt_range', 'annual_inc_range',
           'int_rate_range','loan_status', 'next_pymnt_d','emp_title'
           ,'pymnt_plan','initial_list_status', 'total_rec_late_fee'],axis=1, inplace=True)
#loan.isna()
#loan.isnull().sum()

# %%
#get the data types of the columns
loan.dtypes
#loan.select_dtypes(include=['object'])
dataTypeDict = dict(loan.dtypes)
print(dataTypeDict)
# Out:
# {'loan_amnt': dtype('float64'), 'term': dtype('O'), 'int_rate': dtype('float64'), 'installment': dtype('float64'), 'sub_grade': dtype('int64'), 'emp_length': dtype('O'), 'home_ownership': dtype('int64'), 'annual_inc': dtype('float64'), 'verification_status': dtype('int64'), 'dti': dtype('float64'), 'delinq_2yrs': dtype('float64'), 'fico_range_low': dtype('float64'), 'fico_range_high': dtype('float64'), 'inq_last_6mths': dtype('float64'), 'mths_since_last_delinq': dtype('float64'), 'open_acc': dtype('float64'), 'pub_rec': dtype('float64'), 'revol_bal': dtype('float64'), 'revol_util': dtype('O'), 'total_acc': dtype('float64'), 'out_prncp': dtype('float64'), 'out_prncp_inv': dtype('float64'), 'last_fico_range_high': dtype('float64'), 'last_fico_range_low': dtype('float64'), 'collections_12_mths_ex_med': dtype('float64'), 'tot_coll_amt': dtype('float64'), 'tot_cur_bal': dtype('float64'), 'open_acc_6m': dtype('float64'), 'open_act_il': dtype('float64'), 'open_il_12m': dtype('float64'), 'open_il_24m': dtype('float64'), 'mths_since_rcnt_il': dtype('float64'), 'total_bal_il': dtype('float64'), 'il_util': dtype('float64'), 'open_rv_12m': dtype('float64'), 'open_rv_24m': dtype('float64'), 'max_bal_bc': dtype('float64'), 'all_util': dtype('float64'), 'total_rev_hi_lim': dtype('float64'), 'inq_fi': dtype('float64'), 'total_cu_tl': dtype('float64'), 'inq_last_12m': dtype('float64'), 'acc_open_past_24mths': dtype('float64'), 'avg_cur_bal': dtype('float64'), 'bc_open_to_buy': dtype('float64'), 'bc_util': dtype('float64'), 'chargeoff_within_12_mths': dtype('float64'), 'delinq_amnt': dtype('float64'), 'mo_sin_old_il_acct': dtype('float64'), 'mo_sin_old_rev_tl_op': dtype('float64'), 'mo_sin_rcnt_rev_tl_op': dtype('float64'), 'mo_sin_rcnt_tl': dtype('float64'), 'mort_acc': dtype('float64'), 'mths_since_recent_bc': dtype('float64'), 'mths_since_recent_inq': dtype('float64'), 'num_accts_ever_120_pd': dtype('float64'), 'num_actv_bc_tl': dtype('float64'), 'num_actv_rev_tl': dtype('float64'), 'num_bc_sats': dtype('float64'), 'num_bc_tl': dtype('float64'), 'num_il_tl': dtype('float64'), 'num_op_rev_tl': dtype('float64'), 'num_rev_accts': dtype('float64'), 'num_rev_tl_bal_gt_0': dtype('float64'), 'num_sats': dtype('float64'), 'num_tl_90g_dpd_24m': dtype('float64'), 'num_tl_op_past_12m': dtype('float64'), 'pct_tl_nvr_dlq': dtype('float64'), 'percent_bc_gt_75': dtype('float64'), 'pub_rec_bankruptcies': dtype('float64'), 'tot_hi_cred_lim': dtype('float64'), 'total_bal_ex_mort': dtype('float64'), 'total_bc_limit': dtype('float64'), 'total_il_high_credit_limit': dtype('float64'), 'hardship_flag': dtype('int64'), 'debt_settlement_flag': dtype('int64'), 'good_loan': dtype('int64'), 'emplen': dtype('float64'), 'earliest_crline_mon': dtype('O'), 'credit_len': dtype('int64'), 'car': dtype('uint8'), 'credit_card': dtype('uint8'), 'debt_consolidation': dtype('uint8'), 'home_improvement': dtype('uint8'), 'house': dtype('uint8'), 'major_purchase': dtype('uint8'), 'medical': dtype('uint8'), 'moving': dtype('uint8'), 'renewable_energy': dtype('uint8'), 'small_business': dtype('uint8'), 'vacation': dtype('uint8'), 'AK': dtype('uint8'), 'AL': dtype('uint8'), 'AR': dtype('uint8'), 'AZ': dtype('uint8'), 'CA': dtype('uint8'), 'CO': dtype('uint8'), 'CT': dtype('uint8'), 'DC': dtype('uint8'), 'DE': dtype('uint8'), 'FL': dtype('uint8'), 'GA': dtype('uint8'), 'HI': dtype('uint8'), 'ID': dtype('uint8'), 'IL': dtype('uint8'), 'IN': dtype('uint8'), 'KS': dtype('uint8'), 'KY': dtype('uint8'), 'LA': dtype('uint8'), 'MA': dtype('uint8'), 'MD': dtype('uint8'), 'ME': dtype('uint8'), 'MI': dtype('uint8'), 'MN': dtype('uint8'), 'MO': dtype('uint8'), 'MS': dtype('uint8'), 'MT': dtype('uint8'), 'NC': dtype('uint8'), 'ND': dtype('uint8'), 'NE': dtype('uint8'), 'NH': dtype('uint8'), 'NJ': dtype('uint8'), 'NM': dtype('uint8'), 'NV': dtype('uint8'), 'NY': dtype('uint8'), 'OH': dtype('uint8'), 'OK': dtype('uint8'), 'OR': dtype('uint8'), 'PA': dtype('uint8'), 'RI': dtype('uint8'), 'SC': dtype(' ...

# %%
loan.select_dtypes(include=['object'])
# Out:
#               term emp_length revol_util earliest_crline_mon
# 0        60 months  10+ years      60.9%                 Aug
# 2        36 months    2 years      18.3%                 Sep
# 3        60 months  10+ years      52.4%                 Nov
# 4        36 months    3 years      74.2%                 Oct
# 5        60 months   < 1 year      40.7%                 Feb
# 6        36 months  10+ years      33.4%                 Feb
# 7        36 months        NaN      36.1%                 Oct
# 9        60 months    8 years        42%                 Nov
# 10       36 months    3 years      34.8%                 Sep
# 11       60 months    5 years      45.3%                 Mar
# 12       60 months    9 years        26%                 Jul
# 13       60 months   < 1 year      73.4%                 Dec
# 14       60 months   < 1 year      49.1%                 Aug
# 15       60 months    6 years      97.3%                 Mar
# 16       60 months  10+ years      76.8%                 May
# 17       36 months  10+ years      19.7%                 Jun
# 18       60 months    5 years      27.9%                 Jul
# 19       36 months  10+ years      31.9%                 Sep
# 20       36 months    4 years        39%                 Feb
# 21       60 months   < 1 year      74.4%                 Nov
# 23       36 months    4 years      37.8%                 Dec
# 24       36 months   < 1 year      28.7%                 Nov
# 25       60 months        NaN         0%                 Jun
# 26       60 months    4 years      33.8%                 Mar
# 27       36 months    9 years      43.5%                 Apr
# 28       36 months  10+ years      23.1%                 Feb
# 29       36 months  10+ years      95.6%                 Aug
# 31       60 months   < 1 year      25.6%                 May
# 32       36 months    8 years      36.4%                 May
# 33       60 months    9 years      52.8%                 Dec
# ...            ...        ...        ...                 ...
# 115540   36 months        NaN      51.8%                 Sep
# 115541   60 months   < 1 year      46.6%                 Dec
# 115542   60 months     1 year        33%                 Mar
# 115543   36 months    5 years      39.1%                 Jul
# 115544   36 months    3 years      52.3%                 Dec
# 115545   36 months    2 years      57.8%                 Sep
# 115546   36 months  10+ years      37.5%                 Mar
# 115547   36 months    3 years        79%                 Apr
# 115548   36 months  10+ years      50.2%                 Oct
# 115549   36 months    5 years       8.3%                 Sep
# 115550   36 months    2 years      39.8%                 Aug
# 115551   36 months  10+ years       8.1%                 Apr
# 115552   36 months  10+ years         0%                 Jun
# 115553   60 months  10+ years      25.9%                 Nov
# 115554   36 months  10+ years      73.4%                 Apr
# 115555   36 months   < 1 year      13.5%                 Aug
# 115557   36 months  10+ years      10.7%                 Dec
# 115558   36 months        NaN       4.9%                 Jan
# 115559   36 months  10+ years      17.7%                 Jul
# 115560   60 months   < 1 year        22%                 Jan
# 115563   60 months        NaN      86.8%                 Nov
# 115564   36 months        NaN      10.2%                 Jan
# 115565   60 months  10+ years      21.1%                 Feb
# 115566   60 months  10+ years        35%                 Mar
# 115567   36 months    4 years      29.6%                 Sep
# 115568   36 months        NaN      13.6%                 May
# 115569   36 months   < 1 year       0.1%                 May
# 115570   36 months  10+ years      49.9%                 Dec
# 115571   60 months    5 years      37.1%                 Sep
# 115572   60 months    7 years        69%                 Jan
#
# [108672 rows x 4 columns]

# %%
#loan dataset considered for model development
loan_final = loan.copy(deep=True)

# %%
#get the data types of the columns
loan_final.dtypes
#loan.select_dtypes(include=['object'])
dataTypeDict = dict(loan_final.dtypes)
print(dataTypeDict)
# Out:
# {'loan_amnt': dtype('float64'), 'term': dtype('O'), 'int_rate': dtype('float64'), 'installment': dtype('float64'), 'sub_grade': dtype('int64'), 'emp_length': dtype('O'), 'home_ownership': dtype('int64'), 'annual_inc': dtype('float64'), 'verification_status': dtype('int64'), 'dti': dtype('float64'), 'delinq_2yrs': dtype('float64'), 'fico_range_low': dtype('float64'), 'fico_range_high': dtype('float64'), 'inq_last_6mths': dtype('float64'), 'mths_since_last_delinq': dtype('float64'), 'open_acc': dtype('float64'), 'pub_rec': dtype('float64'), 'revol_bal': dtype('float64'), 'revol_util': dtype('O'), 'total_acc': dtype('float64'), 'out_prncp': dtype('float64'), 'out_prncp_inv': dtype('float64'), 'last_fico_range_high': dtype('float64'), 'last_fico_range_low': dtype('float64'), 'collections_12_mths_ex_med': dtype('float64'), 'tot_coll_amt': dtype('float64'), 'tot_cur_bal': dtype('float64'), 'open_acc_6m': dtype('float64'), 'open_act_il': dtype('float64'), 'open_il_12m': dtype('float64'), 'open_il_24m': dtype('float64'), 'mths_since_rcnt_il': dtype('float64'), 'total_bal_il': dtype('float64'), 'il_util': dtype('float64'), 'open_rv_12m': dtype('float64'), 'open_rv_24m': dtype('float64'), 'max_bal_bc': dtype('float64'), 'all_util': dtype('float64'), 'total_rev_hi_lim': dtype('float64'), 'inq_fi': dtype('float64'), 'total_cu_tl': dtype('float64'), 'inq_last_12m': dtype('float64'), 'acc_open_past_24mths': dtype('float64'), 'avg_cur_bal': dtype('float64'), 'bc_open_to_buy': dtype('float64'), 'bc_util': dtype('float64'), 'chargeoff_within_12_mths': dtype('float64'), 'delinq_amnt': dtype('float64'), 'mo_sin_old_il_acct': dtype('float64'), 'mo_sin_old_rev_tl_op': dtype('float64'), 'mo_sin_rcnt_rev_tl_op': dtype('float64'), 'mo_sin_rcnt_tl': dtype('float64'), 'mort_acc': dtype('float64'), 'mths_since_recent_bc': dtype('float64'), 'mths_since_recent_inq': dtype('float64'), 'num_accts_ever_120_pd': dtype('float64'), 'num_actv_bc_tl': dtype('float64'), 'num_actv_rev_tl': dtype('float64'), 'num_bc_sats': dtype('float64'), 'num_bc_tl': dtype('float64'), 'num_il_tl': dtype('float64'), 'num_op_rev_tl': dtype('float64'), 'num_rev_accts': dtype('float64'), 'num_rev_tl_bal_gt_0': dtype('float64'), 'num_sats': dtype('float64'), 'num_tl_90g_dpd_24m': dtype('float64'), 'num_tl_op_past_12m': dtype('float64'), 'pct_tl_nvr_dlq': dtype('float64'), 'percent_bc_gt_75': dtype('float64'), 'pub_rec_bankruptcies': dtype('float64'), 'tot_hi_cred_lim': dtype('float64'), 'total_bal_ex_mort': dtype('float64'), 'total_bc_limit': dtype('float64'), 'total_il_high_credit_limit': dtype('float64'), 'hardship_flag': dtype('int64'), 'debt_settlement_flag': dtype('int64'), 'good_loan': dtype('int64'), 'emplen': dtype('float64'), 'earliest_crline_mon': dtype('O'), 'credit_len': dtype('int64'), 'car': dtype('uint8'), 'credit_card': dtype('uint8'), 'debt_consolidation': dtype('uint8'), 'home_improvement': dtype('uint8'), 'house': dtype('uint8'), 'major_purchase': dtype('uint8'), 'medical': dtype('uint8'), 'moving': dtype('uint8'), 'renewable_energy': dtype('uint8'), 'small_business': dtype('uint8'), 'vacation': dtype('uint8'), 'AK': dtype('uint8'), 'AL': dtype('uint8'), 'AR': dtype('uint8'), 'AZ': dtype('uint8'), 'CA': dtype('uint8'), 'CO': dtype('uint8'), 'CT': dtype('uint8'), 'DC': dtype('uint8'), 'DE': dtype('uint8'), 'FL': dtype('uint8'), 'GA': dtype('uint8'), 'HI': dtype('uint8'), 'ID': dtype('uint8'), 'IL': dtype('uint8'), 'IN': dtype('uint8'), 'KS': dtype('uint8'), 'KY': dtype('uint8'), 'LA': dtype('uint8'), 'MA': dtype('uint8'), 'MD': dtype('uint8'), 'ME': dtype('uint8'), 'MI': dtype('uint8'), 'MN': dtype('uint8'), 'MO': dtype('uint8'), 'MS': dtype('uint8'), 'MT': dtype('uint8'), 'NC': dtype('uint8'), 'ND': dtype('uint8'), 'NE': dtype('uint8'), 'NH': dtype('uint8'), 'NJ': dtype('uint8'), 'NM': dtype('uint8'), 'NV': dtype('uint8'), 'NY': dtype('uint8'), 'OH': dtype('uint8'), 'OK': dtype('uint8'), 'OR': dtype('uint8'), 'PA': dtype('uint8'), 'RI': dtype('uint8'), 'SC': dtype(' ...

# %%
#to delete - redundant code - TODO
loan_final.drop(['term','emp_length','revol_util','earliest_crline_mon'],axis=1, inplace=True)

# %%
#loan_final['revol_util'].head()

# %%
#loan_final['term'] = loan_final['term'].str.replace('months', '')
#loan_final['term'] = loan_final['term'].str.strip()
#loan_final['term'] = pd.to_numeric(loan_final['term'])
#loan_final['term'].head()
# Out:
# 0    60
# 2    36
# 3    60
# 4    36
# 5    60
# Name: term, dtype: int64

# %%
#loan_final.select_dtypes(include=['object'])

# %%
# Encoding categorical data for column earliest_crline_mon
#labelencoder_earliest_crline_mon = LabelEncoder()
#loan_final['earliest_crline_mon']= labelencoder_earliest_crline_mon.fit_transform(loan_final['earliest_crline_mon'])

# %%
# Encoding categorical data for column revol_util
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_revol_uti = LabelEncoder()
#loan_final['revol_util'] = loan_final['revol_util'].str.replace('%', '')
#loan_final['revol_util'] = loan_final['revol_util'].str.strip()
#loan_final['revol_util']= labelencoder_revol_uti.fit_transform(loan_final['revol_util'])

# %%
# Encoding categorical data for column emp_length
#loan_final['emp_length'].unique
#labelencoder_emp_length = LabelEncoder()
#loan_final['emp_length'] = loan_final['emp_length'].str.replace('+', '')
#loan_final['emp_length'] = loan_final['emp_length'].str.replace('years', '')
#loan_final['emp_length'] = loan_final['emp_length'].str.replace('year', '')
#loan_final['emp_length'] = loan_final['emp_length'].str.replace('<', '')
#loan_final['emp_length'] = loan_final['emp_length'].str.strip()
#loan_final['emp_length']= labelencoder_emp_length.fit_transform(loan_final['emp_length'].notnull())

# %%
#1. selecting features based on p value
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
label_encoder = LabelEncoder()
X_temp= loan_final[loan_final.columns.difference(['good_loan'])] #except label
y_temp = loan_final['good_loan']

#encode the categorial or string variables to number using encoding 
selected_columns =X_temp.columns
categorical_columns = X_temp.select_dtypes(include='object').columns
for x in categorical_columns:
    X_temp[x] = label_encoder.fit_transform(X_temp[x].astype(str)).astype('float64')

# %%
#Selecting columns based on p-value
from sklearn.feature_selection import SelectKBest

# This models a statistical test known as ANOVA
from sklearn.feature_selection import f_classif
# f_classif allows for negative values, not all do
# chi2 is a very common classification criteria but only allows for positive values

#Ranking the p-value
# keep only the best five features according to p-values of ANOVA test
k_best = SelectKBest(f_classif, k=5)

# %%
anyColumnNullVar = loan_final.isnull().any()
print(loan_final.isnull().any())
#for x in loan_final.isnull().any():
#    print(x);
anyColumnNullVar.to_excel("anyColumnNullVar.xlsx")
# Out:
# loan_amnt                     False
# int_rate                      False
# installment                   False
# sub_grade                     False
# home_ownership                False
# annual_inc                    False
# verification_status           False
# dti                           False
# delinq_2yrs                   False
# fico_range_low                False
# fico_range_high               False
# inq_last_6mths                False
# mths_since_last_delinq        False
# open_acc                      False
# pub_rec                       False
# revol_bal                     False
# total_acc                     False
# out_prncp                     False
# out_prncp_inv                 False
# last_fico_range_high          False
# last_fico_range_low           False
# collections_12_mths_ex_med    False
# tot_coll_amt                  False
# tot_cur_bal                   False
# open_acc_6m                   False
# open_act_il                   False
# open_il_12m                   False
# open_il_24m                   False
# mths_since_rcnt_il            False
# total_bal_il                  False
#                               ...
# MN                            False
# MO                            False
# MS                            False
# MT                            False
# NC                            False
# ND                            False
# NE                            False
# NH                            False
# NJ                            False
# NM                            False
# NV                            False
# NY                            False
# OH                            False
# OK                            False
# OR                            False
# PA                            False
# RI                            False
# SC                            False
# SD                            False
# TN                            False
# TX                            False
# UT                            False
# VA                            False
# VT                            False
# WA                            False
# WI                            False
# WV                            False
# WY                            False
# Individual                    False
# Joint App                     False
# Length: 139, dtype: bool

# %%
# matrix after selecting the top 5 features

k_best.fit_transform(X_temp, y_temp)
print('processing done')
# Out:
# processing done

# %%
# get the p values of columns

k_best.pvalues_

# make a dataframe of features and p-values

# sort that dataframe by p-value

p_values = pd.DataFrame({'column': X_temp.columns, 'p_value':k_best.pvalues_}).sort_values('p_value')

# show the top 5 features

p_values.to_excel("variables_p_values.xlsx")

# %%
#!pip install imblearn

# %%
dict_check_nan = dict(loan_final.isnull().sum())
#loan_final.select_dtypes(include=['object'])
#print(dict_check_nan)

# %%
#np.isnan(loan_final.any()) #and gets False
np.isfinite(loan_final.all()) #and gets True
dict_finite_check = dict(np.isfinite(loan_final.all()))
#print(dict_finite_check)

# %%
#get the data types of the columns
#loan.select_dtypes(include=['object'])
dataTypeDict = dict(loan_final.dtypes)
#print(dataTypeDict)

# %%
#TODO
#loan_final['hardship_flag'] = loan['hardship_flag'].fillna(0.0)

# %%
#final columns considered for model development
for col in loan_final.columns:
    print (col)
# Out:
# loan_amnt
# int_rate
# installment
# sub_grade
# home_ownership
# annual_inc
# verification_status
# dti
# delinq_2yrs
# fico_range_low
# fico_range_high
# inq_last_6mths
# mths_since_last_delinq
# open_acc
# pub_rec
# revol_bal
# total_acc
# out_prncp
# out_prncp_inv
# last_fico_range_high
# last_fico_range_low
# collections_12_mths_ex_med
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_act_il
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_inq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
# hardship_flag
# debt_settlement_flag
# good_loan
# emplen
# credit_len
# car
# credit_card
# debt_consolidation
# home_improvement
# house
# major_purchase
# medical
# moving
# renewable_energy
# small_business
# vacation
# AK
# AL
# AR
# AZ
# CA
# CO
# CT
# DC
# DE
# FL
# GA
# HI
# ID
# IL
# IN
# KS
# KY
# LA
# MA
# MD
# ME
# MI
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# NY
# OH
# OK
# OR
# PA
# RI
# SC
# SD
# TN
# TX
# UT
# VA
# VT
# WA
# WI
# WV
# WY
# Individual
# Joint App

# %%
if set(['hardship_flag']).issubset(loan_final.columns):
    loan_final['hardship_flag'] = loan['hardship_flag'].fillna(0)

# %%
###################SAMPLING##############

from collections import Counter
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import StratifiedKFold

#SMOTE: can increase recall at the cost of precision
#undersampling: if less data overall, minority class gets you less data
#ADASYN will focus on samples which are difficult to classify with NN
X= loan_final[loan_final.columns.difference(['good_loan'])] #except label
y= loan_final['good_loan'].apply(float)
# Out:
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
print(np.any(np.isnan(X)))
print(np.any(np.isnan(y)))
#check for columns having NaN values
loan_final.columns[loan_final.isna().any()].tolist()
# Out:
# False
# False
# []

# %%
loan_final['hardship_flag'].head()
# Out:
# 0    0
# 2    0
# 3    0
# 4    0
# 5    0
# Name: hardship_flag, dtype: int64

# %%
#Split original data-oversample training set-test on original test data
#http://contrib.scikit-learn.org/imbalanced-learn/stable/auto_examples/under-sampling/plot_random_under_sampler.html#sphx-glr-auto-examples-under-sampling-plot-random-under-sampler-py
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import ADASYN, RandomOverSampler, SMOTE 
from imblearn.under_sampling import RandomUnderSampler

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2, random_state=0, stratify=y)

# %%
X_train = X_train.astype(np.float32) 
X_test = X_test.astype(np.float32)

# %%
def standardize(train, test):
    mean = np.mean(train, axis=0)
    std = np.std(train, axis=0)+0.000001
    X_train = (train - mean) / std
    X_test = (test - mean) /std
    return X_train, X_test

# %%
X_train, X_test = standardize(X_train,X_test)
#y_train, y_test = standardize(y_train,y_test)

# %%
print(np.any(np.isnan(X_train)))
print(np.any(np.isnan(y_train)))
print(np.any(np.isnan(X_test)))
print(np.any(np.isnan(y_test)))
# Out:
# False
# False
# False
# False

# %%
df1 = X_train[X_train.isna().any(axis=1)]
#print (df1.isna().any(axis=1))
#df1.ix[54199]
df2 = X_train['percent_bc_gt_75']
df2.head()
# Out:
# 63987    -0.958737
# 112130    0.503470
# 111594    1.965676
# 24871    -0.958737
# 40839    -0.958737
# Name: percent_bc_gt_75, dtype: float32

# %%
#stadardization
#from sklearn import preprocessing
#from sklearn.preprocessing import StandardScaler
#scaler = StandardScaler()
#X_std= scaler.fit_transform(X_train)
#X_std_test= scaler.fit_transform(X_test)

# %%
#!pip install openpyxl

# %%
import openpyxl
type(X_train)
X_train.head().to_excel("test_p2p.xlsx")
y_train.head().to_excel("y_train.xlsx")
print("Saved xlsx file")
# Out:
# Saved xlsx file

# %%
type(y_train)
y_train[0]
# Out:
# 1.0

# %%
# Check if 81 exist in DataFrame
if "Nov" in X_train.values:
    print('Element exists in Dataframe')
#X_train.isin(["Nov"]).head()
# Out:
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison

# %%
def percentage_difference(y_true, y_pred):
    return K.mean(abs(y_pred/y_true - 1) * 100)

# %%
#imports for cnn model
from __future__ import print_function
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten,LeakyReLU
from keras.layers import Conv2D, MaxPooling2D
import os
from keras.layers import Flatten, Conv1D, MaxPooling1D, Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization

nSNP=X_train.shape[1]  # no. of SNPs in data
nStride=2 # stride between convolutions
nFilter=32 # no. of convolutions

# %%
# The data, split between train and test sets: - done already
print('x_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
print('input_shape=',X_train.shape[1:])
print('number of features=',X_train.shape[0:])
# Out:
# x_train shape: (86937, 138)
# 86937 train samples
# 21735 test samples
# input_shape= (138,)
# number of features= (86937, 138)

# %%
# no. of SNPs in data
nSNP = X_train.shape[1]
print(nSNP)
# Out:
# 138

# %%
#expand the loan data dimension from lower(1 D) to higher (2D) for CNN input layer
X_train_exp = np.expand_dims(X_train, axis=2)
X_test_exp = np.expand_dims(X_test, axis=2)

# %%
print(X_train_exp.shape)
# Out:
# (86937, 138, 1)

# %%
X_train_exp.shape[1]
# Out:
# 138

# %%
#get the trained model of CNN DenseNet without dropout
from tensorflow import keras
model = keras.models.load_model("model_cnn_densenet_1")

# %%
#CNN model with batch normalization - model 1
model = Sequential()
# add first convolutional layer 1
#184302, 138
model.add(Conv1D(32, 
    kernel_size=3, 
    strides=nStride,
    input_shape=(X_train_exp.shape[1],1)))
# add pooling layer: here takes maximum of two consecutive values
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2))

# add second convolutional layer 2
model.add(Conv1D(64, 
    kernel_size=3, 
    strides=nStride,
    input_shape=(X_train_exp.shape[1],1)))
# add pooling layer: here takes maximum of two consecutive values
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2))


# linear layer - Solutions above are linearized to accommodate a standard layer
model.add(Flatten())
model.add(Dense(124))
model.add(LeakyReLU(alpha=0.1))
#model.add(Dropout(0.25))
#classification layer
model.add(Dense(1))
model.add(Activation('sigmoid'))
#model.add(Dense(1))

# %%
#CNN model with batch normalization - model 2
model = Sequential()
# add first convolutional layer 1
model.add(Conv1D(32, 
    kernel_size=3, 
    strides=nStride,
    input_shape=(X_train_exp.shape[1],1)))
# add pooling layer: here takes maximum of two consecutive values
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2))

#dense block layer 2
model.add(Dense(128))
model.add(LeakyReLU(alpha=0.1))

# add second convolutional layer 3
model.add(Conv1D(64, 
    kernel_size=3, 
    strides=nStride))
# add pooling layer: here takes maximum of two consecutive values
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2))

#dense block layer 4
model.add(Dense(128))
model.add(LeakyReLU(alpha=0.1))


# linear layer - Solutions above are linearized to accommodate a standard layer 5
model.add(Flatten())
model.add(Dense(124))
model.add(LeakyReLU(alpha=0.1))
#model.add(Dropout(0.25))
#classification layer 6
model.add(Dense(1))
model.add(Activation('softmax'))
#model.add(Dense(1))

# %%
# Model Compiling 
# Compile model
from keras.optimizers import SGD
from keras import backend as K
opt = SGD(lr=0.01, momentum=0.9, decay=0.01)
#model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
#model.compile(loss= 'mean_squared_error',optimizer='Adam', metrics=['accuracy',percentage_difference])
model.compile(loss= 'mean_squared_error',optimizer='Adam', metrics=['accuracy'])

# %%
# list some properties of the network
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 68, 32)            128
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 68, 32)            128
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 34, 32)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 16, 64)            6208
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 64)            256
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 8, 64)             0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 124)               63612
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 124)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 125
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 70,457
# Trainable params: 70,265
# Non-trainable params: 192
# _________________________________________________________________

# %%
# Training
from keras.utils import np_utils
from keras.callbacks import ReduceLROnPlateau, CSVLogger, EarlyStopping
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1), cooldown=0, patience=5, min_lr=0.5e-6)
early_stopper = EarlyStopping(min_delta=0.001, patience=10)
history = model.fit(X_train_exp, y_train, epochs=50,
                   validation_data=(X_test_exp, y_test),
                    #callbacks=[lr_reducer, early_stopper],
                    shuffle=True)
# Out:
# Train on 86937 samples, validate on 21735 samples
# Epoch 1/50
# 86937/86937 [==============================] - 53s 614us/step - loss: 0.0403 - acc: 0.9545 - val_loss: 0.0346 - val_acc: 0.9598
# Epoch 2/50
# 86937/86937 [==============================] - 24s 280us/step - loss: 0.0355 - acc: 0.9587 - val_loss: 0.0379 - val_acc: 0.9557
# 86937/86937 [==============================] - 24s 277us/step - loss: 0.0202 - acc: 0.9787 - val_loss: 0.0420 - val_acc: 0.9539
# Epoch 44/50
# 86937/86937 [==============================] - 25s 283us/step - loss: 0.0202 - acc: 0.9786 - val_loss: 0.0466 - val_acc: 0.9478
# Epoch 45/50
# 86937/86937 [==============================] - 24s 279us/step - loss: 0.0198 - acc: 0.9792 - val_loss: 0.0420 - val_acc: 0.9544
# Epoch 46/50
# 86937/86937 [==============================] - 24s 280us/step - loss: 0.0197 - acc: 0.9794 - val_loss: 0.0417 - val_acc: 0.9544
# Epoch 47/50
# 86937/86937 [==============================] - 24s 278us/step - loss: 0.0194 - acc: 0.9795 - val_loss: 0.0418 - val_acc: 0.9546
# Epoch 48/50
# 86937/86937 [==============================] - 25s 282us/step - loss: 0.0193 - acc: 0.9798 - val_loss: 0.0422 - val_acc: 0.9547
# Epoch 49/50
# 86937/86937 [==============================] - 24s 280us/step - loss: 0.0193 - acc: 0.9798 - val_loss: 0.0427 - val_acc: 0.9532
# Epoch 50/50
# 86937/86937 [==============================] - 24s 279us/step - loss: 0.0195 - acc: 0.9793 - val_loss: 0.0416 - val_acc: 0.9558

# %%
# save the deep dense CNN trained model for future reference
model.save("model_cnn_densenet_1")
print("saving model_cnn_densenet_1 done")
# Out:
# saving model_cnn_densenet_1 done

# %%
#!pip install pydot_ng 
#!pip3 install graphviz
#!pip install pydot
#os.environ["PATH"] += os.pathsep + '/mnt/disks/user/anaconda3/lib/python3.6/site-packages/graphviz/dot'
def _check_pydot():
    try:
        # Attempt to create an image of a blank graph
        # to check the pydot/graphviz installation.
        pydot.Dot.create(pydot.Dot())
    except Exception:
        # pydot raises a generic Exception here,
        # so no specific class can be caught.
        raise ImportError('Failed to import pydot. You must install pydot'
                          ' and graphviz for `pydotprint` to work.')
_check_pydot
print("==>",os.path.exists('/mnt/disks/user/anaconda3/lib/python3.6/site-packages/graphviz'))
#pydot.Dot.create(pydot.Dot()
# Out:
# Requirement already satisfied: pydot_ng in /mnt/disks/user/anaconda3/lib/python3.6/site-packages (2.0.0)
# Requirement already satisfied: pyparsing>=2.0.1 in /mnt/disks/user/anaconda3/lib/python3.6/site-packages (from pydot_ng) (2.2.0)
# WARNING: You are using pip version 20.1; however, version 20.1.1 is available.
# You should consider upgrading via the '/mnt/disks/user/anaconda3/bin/python -m pip install --upgrade pip' command.
# ==> True

# %%
#!pip install pydot
#!pip install pydotplus
#!pip install graphviz
#!pip install ann_visualizer
import pydot
import os
import sys
print(os.environ['HOME'])

os.environ["PATH"] += os.pathsep + '/mnt/disks/user/anaconda3/lib/python3.6/site-packages/graphviz'
for p in sys.path:
    print(p)
print('environment path=',os.environ['PATH']) 
print("os.path.exists = ",os.path.exists('/usr/bin/dot'))
#tempfilenames = glob.glob("/mnt/disks/user/anaconda3/envs/")
tempfilenames = glob.glob("/mnt/disks/user/anaconda3/lib/*")
#for fname in tempfilenames:
#    print(fname)
#dirs = os.listdir('/mnt/disks/user/anaconda3/lib/python3.6/site-packages/')  
#dirs = os.listdir('/mnt/disks/user/anaconda3/lib/python3.6/site-packages/') 
dirs = os.listdir('/mnt/disks/user/anaconda3/lib/python3.6/site-packages/graphviz/')  
#dirs = os.listdir('/usr/bin/') 
count = 1
for dname in dirs:
    print(count, ".)", dname)
    count += 1
# Out:
# /root
#
# /mnt/disks/user/anaconda3/lib/python36.zip
# /mnt/disks/user/anaconda3/lib/python3.6
# /mnt/disks/user/anaconda3/lib/python3.6/lib-dynload
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/torchvision-0.2.1-py3.6.egg
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/IPython/extensions
# /root/.ipython
# environment path= /mnt/disks/user/anaconda3/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/snap/bin:/mnt/disks/user/anaconda3/lib/python3.6/site-packages/graphviz/dot:/mnt/disks/user/anaconda3/lib/python3.6/site-packages/graphviz
# os.path.exists =  False
# 1 .) files.py
# 2 .) backend.py
# 3 .) lang.py
# 4 .) __init__.py
# 5 .) dot.py
# 6 .) __pycache__
# 7 .) _compat.py
# 8 .) tools.py

# %%
import pydot_ng as pydot
from keras.utils.vis_utils import plot_model
pydot.find_graphviz()
#plot_model(model,show_shapes=True,to_file="cnn_dense_model_p2p.png")

# %%
# evaluate the model
scores = model.evaluate(X_train_exp, y_train)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 86937/86937 [==============================] - 7s 79us/step
#
# acc: 98.01%

# %%
y_test.head()
# Out:
# 91773    1.0
# 19966    1.0
# 2330     1.0
# 83986    1.0
# 12552    1.0
# Name: good_loan, dtype: float64

# %%
from sklearn.metrics import classification_report
y_val_pred=model.predict_classes(X_test_exp)
print(type(y_val_pred))
print(classification_report(y_test, y_val_pred))
# Out:
# <class 'numpy.ndarray'>
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.47      0.58      1415
#          1.0       0.96      0.99      0.98     20320
#
#     accuracy                           0.96     21735
#    macro avg       0.86      0.73      0.78     21735
# weighted avg       0.95      0.96      0.95     21735

# %%
def get_classification_metric(testy, probs):
    from sklearn.metrics import precision_recall_curve
    precision, recall, thresholds = precision_recall_curve(testy, probs)
    print("precision=",precision)
    print("recall=",recall)
    print("thresholds=",thresholds)
    # convert to f score
    fscore = (2 * precision * recall) / (precision + recall)
    # locate the index of the largest f score
    ix = np.argmax(fscore)
    print("fscore",fscore)
    return fscore[ix]

# %%
from sklearn.metrics import roc_curve, auc


def generate_results(y_test, y_score):
    BIGGER_SIZE = 30
    fpr, tpr, _ = roc_curve(y_test, y_score)
    roc_auc = auc(fpr, tpr)
    plt.figure()
    plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.05])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate',fontsize=30)
    plt.ylabel('True Positive Rate',fontsize=30)
    plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
    plt.rc('ytick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
    plt.title('Receiver operating characteristic curve',fontsize=30)
    plt.show()
    print('AUC: %f' % roc_auc)

# %%
y_pred=model.predict(X_test_exp)

# %%
print('Generating results')
generate_results(y_test, y_pred)
# Out:
# Generating results
# AUC: 0.848695

# %%
#get model performance metrics
y_val_pred=model.predict_classes(X_test_exp)
get_classification_metric(y_test, y_val_pred)
# Out:
# precision= [0.93489763 0.96386812 1.        ]
# recall= [1.        0.9898622 0.       ]
# thresholds= [0 1]
# fscore [0.96635358 0.97669224 0.        ]
# 0.976692240458386

# %%
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy',fontsize=30)
plt.ylabel('accuracy',fontsize=20)
plt.xlabel('epoch',fontsize=20)
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss',fontsize=30)
plt.ylabel('loss',fontsize=20)
plt.xlabel('epoch',fontsize=20)
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
#get the trained densednet - model model_cnn_densenet_2
#from tensorflow import keras
#model = keras.models.load_model("model_cnn_densenet_2")

# %%
#CNN model with batch normalization - model 3
model_cnn_densenet_2 = Sequential()
# add first convolutional layer 1
#184302, 138
model_cnn_densenet_2.add(Conv1D(32, 
    kernel_size=3, 
    strides=nStride,
    input_shape=(X_train_exp.shape[1],1)))
# add pooling layer: here takes maximum of two consecutive values
model_cnn_densenet_2.add(BatchNormalization())
model_cnn_densenet_2.add(MaxPooling1D(pool_size=2))
model_cnn_densenet_2.add(Dropout(0.25))
# add second convolutional layer 2
model_cnn_densenet_2.add(Conv1D(64, 
    kernel_size=2, 
    strides=nStride,
    input_shape=(X_train_exp.shape[1],1)))
# add pooling layer: here takes maximum of two consecutive values
model_cnn_densenet_2.add(BatchNormalization())
model_cnn_densenet_2.add(MaxPooling1D(pool_size=2))
model_cnn_densenet_2.add(Dropout(0.25))

# linear layer - Solutions above are linearized to accommodate a standard layer
model_cnn_densenet_2.add(Flatten())
model_cnn_densenet_2.add(Dense(124))
model_cnn_densenet_2.add(LeakyReLU(alpha=0.1))
model_cnn_densenet_2.add(Dropout(0.25))
#classification layer
model_cnn_densenet_2.add(Dense(1))
model_cnn_densenet_2.add(Activation('sigmoid'))
#model_cnn_densenet_2.add(Dense(1))

# %%
#CNN model with batch normalization - model 4
model_cnn_densenet_2 = Sequential()
# add first convolutional layer 1
#184302, 138
#convolution layer 1
model_cnn_densenet_2.add(Conv1D(32, 
    kernel_size=3, 
    strides=nStride,
    input_shape=(X_train_exp.shape[1],1)))
model_cnn_densenet_2.add(BatchNormalization())
model_cnn_densenet_2.add(MaxPooling1D(pool_size=2))
model_cnn_densenet_2.add(Dropout(0.25))

#dense block layer 2
model_cnn_densenet_2.add(Dense(128))
model_cnn_densenet_2.add(LeakyReLU(alpha=0.1))
model_cnn_densenet_2.add(Dropout(0.25))

# add second convolutional layer 3
model_cnn_densenet_2.add(Conv1D(64, 
    kernel_size=2, 
    strides=nStride,
    input_shape=(X_train_exp.shape[1],1)))
model_cnn_densenet_2.add(BatchNormalization())
model_cnn_densenet_2.add(MaxPooling1D(pool_size=2))
model_cnn_densenet_2.add(Dropout(0.25))

#dense block layer 4
model_cnn_densenet_2.add(Dense(128))
model_cnn_densenet_2.add(LeakyReLU(alpha=0.1))
model_cnn_densenet_2.add(Dropout(0.25))

# linear layer - Solutions above are linearized to accommodate a standard layer
model_cnn_densenet_2.add(Flatten())
model_cnn_densenet_2.add(Dense(124))
model_cnn_densenet_2.add(LeakyReLU(alpha=0.1))
model_cnn_densenet_2.add(Dropout(0.25))
#classification layer
model_cnn_densenet_2.add(Dense(1))
model_cnn_densenet_2.add(Activation('softmax'))
#model_cnn_densenet_2.add(Dense(1))

# %%
# Model Compiling 
# Compile model
from keras.optimizers import SGD
from keras import backend as K
opt = SGD(lr=0.01, momentum=0.9, decay=0.01)
#model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
#model.compile(loss= 'mean_squared_error',optimizer='Adam', metrics=['accuracy',percentage_difference])
model_cnn_densenet_2.compile(loss= 'mean_squared_error',optimizer='Adam', metrics=['accuracy'])

# %%
model_cnn_densenet_2.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_3 (Conv1D)            (None, 68, 32)            128
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 68, 32)            128
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 34, 32)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 34, 32)            0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 17, 64)            4160
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 17, 64)            256
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 8, 64)             0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 64)             0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 124)               63612
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 124)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 124)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 125
# _________________________________________________________________
# activation_2 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 68,409
# Trainable params: 68,217
# Non-trainable params: 192
# _________________________________________________________________

# %%
# Training
from keras.utils import np_utils
from keras.callbacks import ReduceLROnPlateau, CSVLogger, EarlyStopping
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1), cooldown=0, patience=5, min_lr=0.5e-6)
early_stopper = EarlyStopping(min_delta=0.001, patience=10)
history_densenet_2 = model_cnn_densenet_2.fit(X_train_exp, y_train, epochs=100,
                   validation_data=(X_test_exp, y_test),
                    #callbacks=[lr_reducer, early_stopper],
                    shuffle=True)
# Out:
# Train on 86937 samples, validate on 21735 samples
# Epoch 1/100
# 86937/86937 [==============================] - 26s 305us/step - loss: 0.0558 - acc: 0.9412 - val_loss: 0.0380 - val_acc: 0.9567
# Epoch 2/100
# 86937/86937 [==============================] - 26s 294us/step - loss: 0.0393 - acc: 0.9546 - val_loss: 0.0353 - val_acc: 0.9585
# Epoch 3/100
# 86937/86937 [==============================] - 25s 293us/step - loss: 0.0377 - acc: 0.9566 - val_loss: 0.0346 - val_acc: 0.9595
# Epoch 4/100
# 86937/86937 [==============================] - 26s 301us/step - loss: 0.0372 - acc: 0.9568 - val_loss: 0.0350 - val_acc: 0.9593
# Epoch 5/100
# 86937/86937 [==============================] - 26s 297us/step - loss: 0.0369 - acc: 0.9573 - val_loss: 0.0347 - val_acc: 0.9596
# Epoch 6/100
# 86937/86937 [==============================] - 25s 292us/step - loss: 0.0364 - acc: 0.9580 - val_loss: 0.0345 - val_acc: 0.9602
# Epoch 7/100
# 86937/86937 [==============================] - 25s 293us/step - loss: 0.0363 - acc: 0.9581 - val_loss: 0.0344 - val_acc: 0.9601
# Epoch 8/100
# 86937/86937 [==============================] - 25s 293us/step - loss: 0.0362 - acc: 0.9584 - val_loss: 0.0347 - val_acc: 0.9605
# Epoch 89/100
# 86937/86937 [==============================] - 26s 297us/step - loss: 0.0329 - acc: 0.9623 - val_loss: 0.0345 - val_acc: 0.9604
# Epoch 90/100
# 86937/86937 [==============================] - 26s 302us/step - loss: 0.0331 - acc: 0.9622 - val_loss: 0.0342 - val_acc: 0.9609
# Epoch 91/100
# 86937/86937 [==============================] - 26s 293us/step - loss: 0.0329 - acc: 0.9623 - val_loss: 0.0344 - val_acc: 0.9603
# Epoch 92/100
# 86937/86937 [==============================] - 26s 293us/step - loss: 0.0330 - acc: 0.9621 - val_loss: 0.0341 - val_acc: 0.9607
# Epoch 93/100
# 86937/86937 [==============================] - 25s 290us/step - loss: 0.0330 - acc: 0.9618 - val_loss: 0.0339 - val_acc: 0.9609
# Epoch 94/100
# 86937/86937 [==============================] - 25s 289us/step - loss: 0.0329 - acc: 0.9623 - val_loss: 0.0342 - val_acc: 0.9600
# Epoch 95/100
# 86937/86937 [==============================] - 25s 288us/step - loss: 0.0327 - acc: 0.9626 - val_loss: 0.0341 - val_acc: 0.9601
# Epoch 96/100
# 86937/86937 [==============================] - 26s 297us/step - loss: 0.0327 - acc: 0.9625 - val_loss: 0.0343 - val_acc: 0.9605
# Epoch 97/100
# 86937/86937 [==============================] - 25s 292us/step - loss: 0.0329 - acc: 0.9619 - val_loss: 0.0343 - val_acc: 0.9602
# Epoch 98/100
# 86937/86937 [==============================] - 25s 291us/step - loss: 0.0327 - acc: 0.9624 - val_loss: 0.0345 - val_acc: 0.9601
# Epoch 99/100
# 86937/86937 [==============================] - 25s 291us/step - loss: 0.0329 - acc: 0.9619 - val_loss: 0.0339 - val_acc: 0.9608
# Epoch 100/100
# 86937/86937 [==============================] - 25s 291us/step - loss: 0.0329 - acc: 0.9620 - val_loss: 0.0341 - val_acc: 0.9602

# %%
model_cnn_densenet_2.save("model_cnn_densenet_2")
print('saving model_cnn_densenet_2 done')
# Out:
# saving model_cnn_densenet_2 done

# %%
#get model performance metrics
y_val_pred=model_cnn_densenet_2.predict_classes(X_test_exp)
get_classification_metric(y_test, y_val_pred)
# Out:
# precision= [0.93489763 0.96465081 1.        ]
# recall= [1.         0.99379921 0.        ]
# thresholds= [0 1]
# fscore [0.96635358 0.9790081  0.        ]
# 0.9790080961846124

# %%
y_pred=model_cnn_densenet_2.predict(X_test_exp)

# %%
y_val_pred.shape
# Out:
# (21735, 1)

# %%
# list all data in history
print(history_densenet_2.history.keys())
# summarize history for accuracy
plt.plot(history_densenet_2.history['acc'])
plt.plot(history_densenet_2.history['val_acc'])
plt.title('model accuracy',fontsize=30)
plt.ylabel('accuracy',fontsize=20)
plt.xlabel('epoch',fontsize=20)
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history_densenet_2.history['loss'])
plt.plot(history_densenet_2.history['val_loss'])
plt.title('model loss',fontsize=30)
plt.ylabel('loss',fontsize=20)
plt.xlabel('epoch',fontsize=20)
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
print('Generating results')
generate_results(y_test, y_pred)
# Out:
# Generating results
# AUC: 0.868678

# %%
# all resnet models starts here
#resnet model 18
#expand the loan data dimension from lower(1 D) to higher (2D) for CNN input layer
from keras.utils import np_utils
from keras.callbacks import ReduceLROnPlateau, CSVLogger, EarlyStopping

import numpy as np
import resnet

X_train_exp = np.expand_dims(X_train, axis=2)
X_test_exp = np.expand_dims(X_test, axis=2)
y_train_exp = np.expand_dims(y_train, axis=2)
y_test_exp = np.expand_dims(y_test, axis=2)
#print(X_test_exp.shape[0])
#print(X_test_exp.shape[1])
#print(X_test_exp.shape[2])
Y_train = np_utils.to_categorical(y_train, 2)
Y_test = np_utils.to_categorical(y_test, 2)

X_train_new = np.reshape(X_train_exp,(X_train_exp.shape[0],1,X_train_exp.shape[1],1))
X_test_new = np.reshape(X_test_exp,(X_test_exp.shape[0],1,  X_test_exp.shape[1],1))

y_train_new = np.reshape(y_train_exp,(y_train_exp.shape[0], y_train_exp.shape[1]))
y_test_new = np.reshape(y_test_exp,(y_test_exp.shape[0], y_test_exp.shape[1]))
print("X_train_exp.shape" ,X_train_exp.shape)
print("y_train_exp.shape)",y_train_exp.shape)
print("X_train_new.shape)",X_train_new.shape)
print("y_train_new.shape=",y_train_new.shape)
#print(y_train_new)
# Out:
# X_train_exp.shape (86937, 138, 1)
# y_train_exp.shape) (86937, 1)
# X_train_new.shape) (86937, 1, 138, 1)
# y_train_new.shape= (86937, 1)
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   if sys.path[0] == '':
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   del sys.path[0]

# %%
#X_train_new
#print("",type(y_train_new[(0][0]))
y_train[0:5]
y_test[0:5]
# Out:
# 91773    1.0
# 19966    1.0
# 2330     1.0
# 83986    1.0
# 12552    1.0
# Name: good_loan, dtype: float64

# %%
print(np.any(np.isnan(X_test)))
print(np.any(np.isnan(X_test_exp)))
print(np.any(np.isnan(y_test)))
# Out:
# False
# False
# False

# %%
#model with resnet 18

data_rows=len(X_train)
data_cols=len(X_train.columns)
print('rows of X_train',len(X_train))
print('cols  of X_train',len(X_train.columns))
resnet_model = resnet.ResnetBuilder.build_resnet_18((1,1,X_train_exp.shape[1]), 2)
#resnet_model = resnet.ResnetBuilder.build_resnet_18((1,1,256), 2)
# Out:
# rows of X_train 86937
# cols  of X_train 138

# %%
# Model Compiling 
# Compile model
import tensorflow as tf
from keras.optimizers import SGD
from keras.optimizers import adam
from keras import backend as K
from tensorflow.keras import layers
opt = SGD(lr=0.01, momentum=0.9, decay=0.01)
#optimizer = tf.keras.optimizers.Adam(lr=params['learning_rate'])
#model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
#model.compile(loss= 'mean_squared_error',optimizer='Adam', metrics=['accuracy',percentage_difference])
#model.compile(loss= 'mean_squared_error',optimizer='Adam', metrics=['accuracy'])
opt = adam(lr=0.001, decay=1e-6)
resnet_model.compile(loss= 'sparse_categorical_crossentropy',optimizer=opt, metrics=['accuracy'])
#resnet_model.compile(loss= 'sparse_categorical_crossentropy',optimizer=optimizer, metrics=['accuracy'])

# %%
# list some properties of the network
resnet_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 1, 138, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 1, 69, 64)    3200        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 1, 69, 64)    256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 1, 69, 64)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 1, 35, 64)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 1, 35, 64)    36928       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 1, 35, 64)    256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 1, 35, 64)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 1, 35, 64)    36928       activation_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 1, 35, 64)    0           max_pooling2d_1[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 1, 35, 64)    256         add_1[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 1, 35, 64)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 1, 35, 64)    36928       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 1, 35, 64)    256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 1, 35, 64)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 1, 35, 64)    36928       activation_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 1, 35, 64)    0           add_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 1, 35, 64)    256         add_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 1, 35, 64)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 1, 18, 128)   73856       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 1, 18, 128)   512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 1, 18, 128)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 1, 18, 128)   8320        add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 1, 18, 128)   147584      activation_8[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 1, 18, 128)   0           conv2d_8[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 1, 18, 128)   512         add_3[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 1, 18, 128)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 1, 18, 128)   147584      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 1, 18, 128)   512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 1, 18, 128)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 1, 18, 128)   147584      activation_10[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 1, 18, 128)   0           add_3[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 1, 18, 128)   512         add_4[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 1, 18, 128)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 1, 9, 256)    295168      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 1, 9, 256)    1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 1, 9, 256)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 1, 9, 256)    33024       add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 1, 9, 256)    590080      activation_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 1, 9, 256)    0           conv2d_13[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 1, 9, 256)    1024        add_5[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 1, 9, 256)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 1, 9, 256)    590080      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 1, 9, 256)    1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 1, 9, 256)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 1, 9, 256)    590080      activation_14[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 1, 9, 256)    0           add_5[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 1, 9, 256)    1024        add_6[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 1, 9, 256)    0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 1, 5, 512)    1180160     activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 1, 5, 512)    2048        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 1, 5, 512)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 1, 5, 512)    131584      add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 1, 5, 512)    2359808     activation_16[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 1, 5, 512)    0           conv2d_18[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 1, 5, 512)    2048        add_7[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 1, 5, 512)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 1, 5, 512)    2359808     activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 1, 5, 512)    2048        conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 1, 5, 512)    0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 1, 5, 512)    2359808     activation_18[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 1, 5, 512)    0           add_7[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 1, 5, 512)    2048        add_8[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 1, 5, 512)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 512)    0           activation_19[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 512)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 2)            1026        flatten_3[0][0]
# ==================================================================================================
# Total params: 11,182,082
# Trainable params: 11,174,274
# Non-trainable params: 7,808
# __________________________________________________________________________________________________

# %%
# Training
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1), cooldown=0, patience=5, min_lr=0.5e-6)
early_stopper = EarlyStopping(min_delta=0.001, patience=10)
history_resnet = resnet_model.fit(X_train_new, y_train, epochs=50,
                   validation_data=(X_test_new, y_test),
                   shuffle=True,
                    callbacks=[lr_reducer])
#resnet_model.fit(X_train_new, y_train_new,
#              batch_size=32,
#              epochs=50,
#              validation_data=(X_test_new, y_test_new),
#              callbacks=[lr_reducer, early_stopper])
# Out:
           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 1, 18, 128)   73856       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 1, 18, 128)   512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 1, 18, 128)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 1, 18, 128)   8320        add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 1, 18, 128)   147584      activation_8[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 1, 18, 128)   0           conv2d_8[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 1, 18, 128)   512         add_3[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 1, 18, 128)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 1, 18, 128)   147584      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 1, 18, 128)   512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 1, 18, 128)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 1, 18, 128)   147584      activation_10[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 1, 18, 128)   0           add_3[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 1, 18, 128)   512         add_4[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 1, 18, 128)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 1, 9, 256)    295168      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 1, 9, 256)    1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 1, 9, 256)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 1, 9, 256)    33024       add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 1, 9, 256)    590080      activation_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 1, 9, 256)    0           conv2d_13[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 1, 9, 256)    1024        add_5[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 1, 9, 256)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 1, 9, 256)    590080      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 1, 9, 256)    1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 1, 9, 256)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 1, 9, 256)    590080      activation_14[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 1, 9, 256)    0           add_5[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 1, 9, 256)    1024        add_6[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 1, 9, 256)    0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 1, 5, 512)    1180160     activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 1, 5, 512)    2048        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 1, 5, 512)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 1, 5, 512)    131584      add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 1, 5, 512)    2359808     activation_16[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 1, 5, 512)    0           conv2d_18[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 1, 5, 512)    2048        add_7[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 1, 5, 512)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 1, 5, 512)    2359808     activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 1, 5, 512)    2048        conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 1, 5, 512)    0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 1, 5, 512)    2359808     activation_18[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 1, 5, 512)    0           add_7[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 1, 5, 512)    2048        add_8[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 1, 5, 512)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 512)    0           activation_19[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 512)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 2)            1026        flatten_3[0][0]
# ==================================================================================================
# Total params: 11,182,082
# Trainable params: 11,174,274
# Non-trainable params: 7,808
# __________________________________________________________________________________________________

# %%
def get_classification_metric_resnet(testy, probs):
    from sklearn.metrics import precision_recall_curve
    precision, recall, thresholds = precision_recall_curve(testy, probs[:,1])
    ix_precision = np.argmax(precision)
    precision_val = np.average(precision)
    print("precision=",precision)
    ix_recall = np.argmax(recall)
    recall_val = np.average(recall)
    print("recall=",recall)
    print("thresholds=",thresholds)
    # convert to f score
    fscore = (2 * precision * recall) / (precision + recall)
    # locate the index of the largest f score
    ix = np.argmax(fscore)
    print("fscore",fscore[ix])
    return fscore[ix]

# %%
#get resnet model performance metrics
from keras.applications.imagenet_utils import decode_predictions 
predictions = loaded_resnet_model.predict(X_test_new) 
#y_pred =(predictions>0.5)
y_pred =  (predictions>0.5) 
y_pred = y_pred.astype(int)
type(y_pred)
#label = decode_predictions(predictions)
get_classification_metric_resnet(y_test, y_pred)
# Out:
# precision= [0.93489763 0.96588895 1.        ]
# recall= [1.        0.9921752 0.       ]
# thresholds= [0 1]
# fscore 0.9788556308110601
# 0.9788556308110601

# %%
predictions
# Out:
# array([[0.00531199, 0.99468803],
#        [0.03554098, 0.964459  ],
#        [0.01191204, 0.98808795],
#        ...,
#        [0.05551387, 0.9444862 ],
#        [0.19721583, 0.80278414],
#        [0.9244659 , 0.0755341 ]], dtype=float32)

# %%
print('Generating results')
generate_results(y_test, predictions[:,1])
# Out:
# Generating results
# AUC: 0.865967

# %%
print(type(y_pred))
#print(classification_report(y_test, y_pred))
# Out:
# <class 'numpy.ndarray'>

# %%
def get_classification_metric(testy, probs):
    from sklearn.metrics import precision_recall_curve
    precision, recall, thresholds = precision_recall_curve(testy, probs[:,1])
    # convert to f score
    fscore = (2 * precision * recall) / (precision + recall)
    # locate the index of the largest f score
    ix = np.argmax(fscore)
    return fscore[ix]

# %%
#print f1-score
predictions = resnet_model.predict(X_test_new) 
get_classification_metric(y_test, predictions)

# %%
from keras.applications.resnet50 import ResNet50 
from keras.applications import resnet50
from keras.applications.imagenet_utils import decode_predictions 

y_val_pred=resnet_model.predict(X_test_new)
#label = decode_predictions(predictions) 
print(label)
#predictions
#print(classification_report(y_test, y_val_pred))

# %%
# evaluate the model
scores_resnset = resnet_model.evaluate(X_train_new, y_train)
print("\n%s: %.2f%%" % (resnet_model.metrics_names[1], scores_resnset[1]*100))
# Out:
# 86937/86937 [==============================] - 40s 455us/step
#
# acc: 96.57%

# %%
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history_resnet.history['acc'])
plt.plot(history_resnet.history['val_acc'])
plt.title('model accuracy',fontsize=30)
plt.ylabel('accuracy',fontsize=20)
plt.xlabel('epoch',fontsize=20)
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history_resnet.history['loss'])
plt.plot(history_resnet.history['val_loss'])
plt.title('model loss',fontsize=30)
plt.ylabel('loss',fontsize=20)
plt.xlabel('epoch',fontsize=20)
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
#profile resnet 18 and visualize results
from util import profile
# analyze FLOPS
layer_name, layer_flops, inshape, weights = profile(resnet_model)

# %%
# visualize results
for name, flop, shape, weight in zip(layer_name, layer_flops, inshape, weights):
    print("layer:", name, shape, " MegaFLOPS:", flop/1e6, " MegaWeights:", weight/1e6)
# Out:
# layer: conv2d_1 (None, 1, 138, 1)  MegaFLOPS: 0.432832  MegaWeights: 0.0032
# layer: conv2d_2 (None, 1, 35, 64)  MegaFLOPS: 2.580544  MegaWeights: 0.036928
# layer: conv2d_3 (None, 1, 35, 64)  MegaFLOPS: 2.580544  MegaWeights: 0.036928
# layer: conv2d_4 (None, 1, 35, 64)  MegaFLOPS: 2.580544  MegaWeights: 0.036928
# layer: conv2d_5 (None, 1, 35, 64)  MegaFLOPS: 2.580544  MegaWeights: 0.036928
# layer: conv2d_6 (None, 1, 35, 64)  MegaFLOPS: 2.654336  MegaWeights: 0.073856
# layer: conv2d_8 (None, 1, 35, 64)  MegaFLOPS: 0.29504  MegaWeights: 0.00832
# layer: conv2d_7 (None, 1, 18, 128)  MegaFLOPS: 5.308544  MegaWeights: 0.147584
# layer: conv2d_9 (None, 1, 18, 128)  MegaFLOPS: 5.308544  MegaWeights: 0.147584
# layer: conv2d_10 (None, 1, 18, 128)  MegaFLOPS: 5.308544  MegaWeights: 0.147584
# layer: conv2d_11 (None, 1, 18, 128)  MegaFLOPS: 5.308672  MegaWeights: 0.295168
# layer: conv2d_13 (None, 1, 18, 128)  MegaFLOPS: 0.59008  MegaWeights: 0.033024
# layer: conv2d_12 (None, 1, 9, 256)  MegaFLOPS: 10.617088  MegaWeights: 0.59008
# layer: conv2d_14 (None, 1, 9, 256)  MegaFLOPS: 10.617088  MegaWeights: 0.59008
# layer: conv2d_15 (None, 1, 9, 256)  MegaFLOPS: 10.617088  MegaWeights: 0.59008
# layer: conv2d_16 (None, 1, 9, 256)  MegaFLOPS: 11.796992  MegaWeights: 1.18016
# layer: conv2d_18 (None, 1, 9, 256)  MegaFLOPS: 1.311232  MegaWeights: 0.131584
# layer: conv2d_17 (None, 1, 5, 512)  MegaFLOPS: 23.593472  MegaWeights: 2.359808
# layer: conv2d_19 (None, 1, 5, 512)  MegaFLOPS: 23.593472  MegaWeights: 2.359808
# layer: conv2d_20 (None, 1, 5, 512)  MegaFLOPS: 23.593472  MegaWeights: 2.359808
# layer: dense_5 (None, 512)  MegaFLOPS: 0.00205  MegaWeights: 0.001026

# %%
#model with resnet 34

data_rows=len(X_train)
data_cols=len(X_train.columns)
print('rows of X_train',len(X_train))
print('cols  of X_train',len(X_train.columns))
resnet_model_34 = resnet.ResnetBuilder.build_resnet_34((1,1,X_train_exp.shape[1]), 2)
#resnet_model = resnet.ResnetBuilder.build_resnet_18((1,1,256), 2)
# Out:
# rows of X_train 86937
# cols  of X_train 138

# %%
# Model Compiling resnet 34 network
# Compile model

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1), cooldown=0, patience=5, min_lr=0.5e-6)
early_stopper = EarlyStopping(min_delta=0.001, patience=10)

import tensorflow as tf
from keras.optimizers import SGD
from keras.optimizers import adam
from keras import backend as K
from tensorflow.keras import layers
opt = SGD(lr=0.01, momentum=0.9, decay=0.01)
#optimizer = tf.keras.optimizers.Adam(lr=params['learning_rate'])
#model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
#model.compile(loss= 'mean_squared_error',optimizer='Adam', metrics=['accuracy',percentage_difference])
#model.compile(loss= 'mean_squared_error',optimizer='Adam', metrics=['accuracy'])
opt = adam(lr=0.001, decay=1e-6)
resnet_model_34.compile(loss= 'sparse_categorical_crossentropy',optimizer=opt, metrics=['accuracy'])
#resnet_model.compile(loss= 'sparse_categorical_crossentropy',optimizer=optimizer, metrics=['accuracy'])

# %%
# list some properties of the model resnet 34 network
# Model Compiling 
resnet_model_34.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 1, 138, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 1, 69, 64)    3200        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 1, 69, 64)    256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1, 69, 64)    0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 1, 35, 64)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 1, 35, 64)    36928       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 1, 35, 64)    256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 1, 35, 64)    0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 1, 35, 64)    36928       activation_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 1, 35, 64)    0           max_pooling2d_1[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 1, 35, 64)    256         add_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 1, 35, 64)    0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 1, 35, 64)    36928       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 1, 35, 64)    256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 1, 35, 64)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 1, 35, 64)    36928       activation_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 1, 35, 64)    0           add_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 1, 35, 64)    256         add_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 1, 35, 64)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 1, 35, 64)    36928       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 1, 35, 64)    256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None,
29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 1, 5, 512)    2048        conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 1, 5, 512)    0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 1, 5, 512)    2359808     activation_30[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 1, 5, 512)    0           add_14[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 1, 5, 512)    2048        add_15[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 1, 5, 512)    0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 1, 5, 512)    2359808     activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 1, 5, 512)    2048        conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 1, 5, 512)    0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 1, 5, 512)    2359808     activation_32[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 1, 5, 512)    0           add_15[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 1, 5, 512)    2048        add_16[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 1, 5, 512)    0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 512)    0           activation_33[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 512)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            1026        flatten_1[0][0]
# ==================================================================================================
# Total params: 21,301,378
# Trainable params: 21,286,146
# Non-trainable params: 15,232
# __________________________________________________________________________________________________

# %%
# Training resnet 34 network
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1), cooldown=0, patience=5, min_lr=0.5e-6)
early_stopper = EarlyStopping(min_delta=0.001, patience=10)
history_resnet_34 = resnet_model_34.fit(X_train_new, y_train, epochs=50,
                   validation_data=(X_test_new, y_test),
                   shuffle=True,
                  callbacks=[lr_reducer])
#                    callbacks=[lr_reducer, early_stopper])
# Out:
# Train on 86937 samples, validate on 21735 samples
# Epoch 1/50
# 86937/86937 [==============================] - 454s 5ms/step - loss: 0.3116 - acc: 0.9501 - val_loss: 0.1832 - val_acc: 0.9556
# Epoch 2/50
# 86937/86937 [==============================] - 428s 5ms/step - loss: 0.1798 - acc: 0.9539 - val_loss: 0.1678 - val_acc: 0.9573
# Epoch 3/50
# 86937/86937 [==============================] - 427s 5ms/step - loss: 0.1718 - acc: 0.9559 - val_loss: 0.2466 - val_acc: 0.9493
# Epoch 4/50
# 86937/86937 [==============================] - 427s 5ms/step - loss: 0.1671 - acc: 0.9572 - val_loss: 0.1602 - val_acc: 0.9590
# Epoch 5/50
# 86937/86937 [==============================] - 427s 5ms/step - loss: 0.1621 - acc: 0.9579 - val_loss: 0.1585 - val_acc: 0.9614
# Epoch 6/50
# 86937/86937 [==============================] - 427s 5ms/step - loss: 0.1586 - acc: 0.9582 - val_loss: 0.1623 - val_acc: 0.9563
# Epoch 7/50
# 86937/86937 [==============================] - 427s 5ms/step - loss: 0.1561 - acc: 0.9582 - val_loss: 0.1856 - val_acc: 0.9486
# Epoch 8/50
# 86937/86937 [==============================] - 427s 5ms/step - loss: 0.1541 - acc: 0.9586 - val_loss: 0.1596 - val_acc: 0.9598
# Epoch 9/50
# 86937/86937 [==============================] - 428s 5ms/step - loss: 0.1525 - acc: 0.9591 - val_loss: 0.1524 - val_acc: 0.9620
# Epoch 10/50
# 86937/86937 [==============================] - 428s 5ms/step - loss: 0.1516 - acc: 0.9588 - val_loss: 0.1581 - val_acc: 0.9598
# Epoch 11/50
# 86937/86937 [==============================] - 427s 5ms/step - loss: 0.1497 - acc: 0.9598 - val_loss: 0.1496 - val_acc: 0.9607
# Epoch 12/50
# 86937/86937 [==============================] - 427s 5ms/step - loss: 0.1490 - acc: 0.9600 - val_loss: 0.1594 - val_acc: 0.9600
# Epoch 13/50
# 86937/86937 [==============================] - 427s 5ms/step - loss: 0.1488 - acc: 0.9594 - val_loss: 0.1501 - val_acc: 0.9609
#label = decode_predictions(predictions)
get_classification_metric_resnet(y_test, y_pred)
# Out:
# precision= [0.93489763 0.96498036 1.        ]
# recall= [1.         0.99128937 0.        ]
# thresholds= [0 1]
# fscore 0.9779579550419966
# 0.9779579550419966

# %%
print('Generating results')
generate_results(y_test, predictions[:,1])
# Out:
# Generating results
# AUC: 0.855938

# %%
# list all data in history
print(history_resnet_34.history.keys())
# summarize history for accuracy
plt.plot(history_resnet_34.history['acc'])
plt.plot(history_resnet_34.history['val_acc'])
plt.title('model accuracy',fontsize=30)
plt.ylabel('accuracy',fontsize=30)
plt.xlabel('epoch',fontsize=30)
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history_resnet_34.history['loss'])
plt.plot(history_resnet_34.history['val_loss'])
plt.title('model loss',fontsize=30)
plt.ylabel('loss',fontsize=30)
plt.xlabel('epoch',fontsize=30)
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc', 'lr'])

# %%
#model with resnet 50

from keras.utils import np_utils
from keras.callbacks import ReduceLROnPlateau, CSVLogger, EarlyStopping

import numpy as np
import resnet

X_train_exp = np.expand_dims(X_train, axis=2)
X_test_exp = np.expand_dims(X_test, axis=2)
y_train_exp = np.expand_dims(y_train, axis=2)
y_test_exp = np.expand_dims(y_test, axis=2)
#print(X_test_exp.shape[0])
#print(X_test_exp.shape[1])
#print(X_test_exp.shape[2])
Y_train = np_utils.to_categorical(y_train, 2)
Y_test = np_utils.to_categorical(y_test, 2)

X_train_new = np.reshape(X_train_exp,(X_train_exp.shape[0],1,X_train_exp.shape[1],1))
X_test_new = np.reshape(X_test_exp,(X_test_exp.shape[0],1,  X_test_exp.shape[1],1))

y_train_new = np.reshape(y_train_exp,(y_train_exp.shape[0], y_train_exp.shape[1]))
y_test_new = np.reshape(y_test_exp,(y_test_exp.shape[0], y_test_exp.shape[1]))
print("X_train_exp.shape" ,X_train_exp.shape)
print("y_train_exp.shape)",y_train_exp.shape)
print("X_train_new.shape)",X_train_new.shape)
print("y_train_new.shape=",y_train_new.shape)
#print(y_train_new)
# Out:
# X_train_exp.shape (86937, 138, 1)
# y_train_exp.shape) (86937, 1)
# X_train_new.shape) (86937, 1, 138, 1)
# y_train_new.shape= (86937, 1)
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   # This is added back by InteractiveShellApp.init_path()
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   if sys.path[0] == '':

# %%
#model with resnet 50

data_rows=len(X_train)
data_cols=len(X_train.columns)
print('rows of X_train',len(X_train))
print('cols  of X_train',len(X_train.columns))
resnet_model_50 = resnet.ResnetBuilder.build_resnet_50((1,1,X_train_exp.shape[1]), 2)
#resnet_model = resnet.ResnetBuilder.build_resnet_50((1,1,256), 2)
# Out:
# rows of X_train 86937
# cols  of X_train 138

# %%
# Model Compiling resnet 34 network
# Compile model

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1), cooldown=0, patience=5, min_lr=0.5e-6)
early_stopper = EarlyStopping(min_delta=0.001, patience=10)

import tensorflow as tf
from keras.optimizers import SGD
from keras.optimizers import adam
from keras import backend as K
from tensorflow.keras import layers
opt = SGD(lr=0.01, momentum=0.9, decay=0.01)
#optimizer = tf.keras.optimizers.Adam(lr=params['learning_rate'])
#model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
#model.compile(loss= 'mean_squared_error',optimizer='Adam', metrics=['accuracy',percentage_difference])
#model.compile(loss= 'mean_squared_error',optimizer='Adam', metrics=['accuracy'])
opt = adam(lr=0.001, decay=1e-6)
resnet_model_50.compile(loss= 'sparse_categorical_crossentropy',optimizer=opt, metrics=['accuracy'])
#resnet_model.compile(loss= 'sparse_categorical_crossentropy',optimizer=optimizer, metrics=['accuracy'])

# %%
#resnet 50 model summary
resnet_model_50.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 1, 138, 1)    0
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 1, 69, 64)    3200        input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 1, 69, 64)    256         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 1, 69, 64)    0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 1, 35, 64)    0           activation_50[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 1, 35, 64)    4160        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 1, 35, 64)    256         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 1, 35, 64)    0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 1, 35, 64)    36928       activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 1, 35, 64)    256         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 1, 35, 64)    0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 1, 35, 256)   16640       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 1, 35, 256)   16640       activation_52[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 1, 35, 256)   0           conv2d_58[0][0]
#                                                                  conv2d_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 1, 35, 256)   1024        add_17[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 1, 35, 256)   0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 1, 35, 64)    16448       activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 1, 35, 64)    256         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 1, 35, 64)    0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 1, 35, 64)    36928       activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 1, 35, 64)    256         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 1, 35, 64)    0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 1, 35, 256)   16640       activation_55[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 1, 35, 256)   0           add_17[0][0]
#                                                                  conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 1, 35, 256)   1024        add_18[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 1, 35, 256)   0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 1, 35, 64)    16448       activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 1, 35, 64)    256         conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 1, 35, 64)    0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 1, 35, 64)    36928       activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 1, 35, 64)    256         conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 1, 35, 64)    0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 1, 35, 256)   16640       activation_58[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 1, 35, 256)   0           add_18[0][0]
#                                                                  conv2d_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 1, 35, 256)   1024        add_19[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 1, 35, 256)   0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 1, 18, 128)   32896       activation_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 1, 18, 128)   512         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 1, 18, 128)   0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 1, 18, 128)   147584      activation_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 1, 18, 128)   512         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 1, 18, 128)   0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 1, 18, 512)   131584      add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 1, 18, 512)   66048       activation_61[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 1, 18, 512)   0           conv2d_68[0][0]
#                                                                  conv2d_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 1, 18, 512)   2048        add_20[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 1, 18, 512)   0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 1, 18, 128)   65664       activation_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 1, 18, 128)   512         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 1, 18, 128)   0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 1, 18, 128)   147584      activation_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 1, 18, 128)   512         conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 1, 18, 128)   0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 1, 18, 512)   66048       activation_64[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 1, 18, 512)   0           add_20[0][0]
#                                                                  conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 1, 18, 512)   2048        add_21[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 1, 18, 512)   0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 1, 18, 128)   65664       activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 1, 18, 128)   512         conv2d_72[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 1, 18, 128)   0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 1, 18, 128)   147584      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 1, 18, 128)   512         conv2d_73[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 1, 18, 128)   0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 1, 18, 512)   66048       activation_67[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 1, 18, 512)   0           add_21[0][0]
#                                                                  conv2d_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 1, 18, 512)   2048        add_22[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 1, 18, 512)   0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 1, 18, 128)   65664       activation_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 1, 18, 128)   512         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 1, 18, 128)   0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 1, 18, 128)   147584      activation_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 1, 18, 128)   512         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 1, 18, 128)   0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 1, 18, 512)   66048       activation_70[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 1, 18, 512)   0           add_22[0][0]
#                                                                  conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 1, 18, 512)   2048        add_23[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 1, 18, 512)   0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 1, 9, 256)    131328      activation_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 1, 9, 256)    1024        conv2d_78[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 1, 9, 256)    0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 1, 9, 256)    590080      activation_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 1, 9, 256)    1024        conv2d_79[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 1, 9, 256)    0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 1, 9, 1024)   525312      add_23[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 1, 9, 1024)   263168      activation_73[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 1, 9, 1024)   0           conv2d_81[0][0]
#                                                                  conv2d_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 1, 9, 1024)   4096        add_24[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 1, 9, 1024)   0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 1, 9, 256)    262400      activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 1, 9, 256)    1024        conv2d_82[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 1, 9, 256)    0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 1, 9, 256)    590080      activation_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 1, 9, 256)    1024        conv2d_83[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 1, 9, 256)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 1, 9, 1024)   263168      activation_76[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 1, 9, 1024)   0           add_24[0][0]
#                                                                  conv2d_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 1, 9, 1024)   4096        add_25[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 1, 9, 1024)   0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 1, 9, 256)    262400      activation_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 1, 9, 256)    1024        conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 1, 9, 256)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 1, 9, 256)    590080      activation_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 1, 9, 256)    1024        conv2d_86[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 1, 9, 256)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 1, 9, 1024)   263168      activation_79[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 1, 9, 1024)   0           add_25[0][0]
#                                                                  conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 1, 9, 1024)   4096        add_26[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 1, 9, 1024)   0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 1, 9, 256)    262400      activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 1, 9, 256)    1024        conv2d_88[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 1, 9, 256)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 1, 9, 256)    590080      activation_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 1, 9, 256)    1024        conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 1, 9, 256)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 1, 9, 1024)   263168      activation_82[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 1, 9, 1024)   0           add_26[0][0]
#                                                                  conv2d_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 1, 9, 1024)   4096        add_27[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 1, 9, 1024)   0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 1, 9, 256)    262400      activation_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 1, 9, 256)    1024        conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 1, 9, 256)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 1, 9, 256)    590080      activation_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 1, 9, 256)    1024        conv2d_92[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 1, 9, 256)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 1, 9, 1024)   263168      activation_85[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 1, 9, 1024)   0           add_27[0][0]
#                                                                  conv2d_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 1, 9, 1024)   4096        add_28[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 1, 9, 1024)   0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 1, 9, 256)    262400      activation_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 1, 9, 256)    1024        conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 1, 9, 256)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 1, 9, 256)    590080      activation_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 1, 9, 256)    1024        conv2d_95[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 1, 9, 256)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 1, 9, 1024)   263168      activation_88[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 1, 9, 1024)   0           add_28[0][0]
#                                                                  conv2d_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 1, 9, 1024)   4096        add_29[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 1, 9, 1024)   0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 1, 5, 512)    524800      activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 1, 5, 512)    2048        conv2d_97[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 1, 5, 512)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 1, 5, 512)    2359808     activation_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 1, 5, 512)    2048        conv2d_98[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 1, 5, 512)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 1, 5, 2048)   2099200     add_29[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 1, 5, 2048)   1050624     activation_91[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 1, 5, 2048)   0           conv2d_100[0][0]
#                                                                  conv2d_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 1, 5, 2048)   8192        add_30[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 1, 5, 2048)   0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 1, 5, 512)    1049088     activation_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 1, 5, 512)    2048        conv2d_101[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 1, 5, 512)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 1, 5, 512)    2359808     activation_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 1, 5, 512)    2048        conv2d_102[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 1, 5, 512)    0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 1, 5, 2048)   1050624     activation_94[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 1, 5, 2048)   0           add_30[0][0]
#                                                                  conv2d_103[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 1, 5, 2048)   8192        add_31[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 1, 5, 2048)   0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 1, 5, 512)    1049088     activation_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 1, 5, 512)    2048        conv2d_104[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 1, 5, 512)    0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 1, 5, 512)    2359808     activation_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 1, 5, 512)    2048        conv2d_105[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 1, 5, 512)    0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 1, 5, 2048)   1050624     activation_97[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 1, 5, 2048)   0           add_31[0][0]
#                                                                  conv2d_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 1, 5, 2048)   8192        add_32[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 1, 5, 2048)   0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 1, 1, 2048)   0           activation_98[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 2048)         0           average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            4098        flatten_2[0][0]
# ==================================================================================================
# Total params: 23,570,178
# Trainable params: 23,524,738
# Non-trainable params: 45,440
# __________________________________________________________________________________________________

# %%
# Training resnet 50 network
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1), cooldown=0, patience=5, min_lr=0.5e-6)
early_stopper = EarlyStopping(min_delta=0.001, patience=10)
history_resnet_50 = resnet_model_50.fit(X_train_new, y_train, epochs=50,
                   validation_data=(X_test_new, y_test),
                   shuffle=True,
                  callbacks=[lr_reducer])
#                    callbacks=[lr_reducer, early_stopper])
# Out:
# Train on 86937 samples, validate on 21735 samples
# Epoch 1/50
# 86937/86937 [==============================] - 581s 7ms/step - loss: 0.6967 - acc: 0.9465 - val_loss: 0.2181 - val_acc: 0.9575
# Epoch 2/50
# 86937/86937 [==============================] - 547s 6ms/step - loss: 0.2188 - acc: 0.9511 - val_loss: 0.1920 - val_acc: 0.9570
# Epoch 3/50
# 86937/86937 [==============================] - 545s 6ms/step - loss: 0.1934 - acc: 0.9534 - val_loss: 0.1769 - val_acc: 0.9578
# Epoch 4/50
# 86937/86937 [==============================] - 545s 6ms/step - loss: 0.1922 - acc: 0.9523 - val_loss: 2.8742 - val_acc: 0.1671
# Epoch 5/50
# 86937/86937 [==============================] - 543s 6ms/step - loss: 0.1836 - acc: 0.9524 - val_loss: 0.2689 - val_acc: 0.9350
# Epoch 6/50
# 86937/86937 [==============================] - 545s 6ms/step - loss: 0.1728 - acc: 0.9538 - val_loss: 0.1671 - val_acc: 0.9568
# Epoch 7/50
# 86937/86937 [==============================] - 545s 6ms/step - loss: 0.1705 - acc: 0.9543 - val_loss: 0.2141 - val_acc: 0.9406
# Epoch 8/50
# 86937/86937 [==============================] - 543s 6ms/step - loss: 0.1691 - acc: 0.9545 - val_loss: 0.1622 - val_acc: 0.9562
# Epoch 9/50
# 86937/86937 [==============================] - 545s 6ms/step - loss: 0.1657 - acc: 0.9550 - val_loss: 0.2129 - val_acc: 0.9396
# Epoch 10/50
# 86937/86937 [==============================] - 546s 6ms/step - loss: 0.1656 - acc: 0.9553 - val_loss: 0.1882 - val_acc: 0.9487
# Epoch 11/50
# 86937/86937 [==============================] - 541s 6ms/step - loss: 0.1624 - acc: 0.9554 - val_loss: 0.2105 - val_acc: 0.9357
# Epoch 12/50
# Epoch 32/50
# 86937/86937 [==============================] - 543s 6ms/step - loss: 0.1396 - acc: 0.9594 - val_loss: 0.1497 - val_acc: 0.9589
# Epoch 33/50
# 86937/86937 [==============================] - 546s 6ms/step - loss: 0.1389 - acc: 0.9597 - val_loss: 0.1497 - val_acc: 0.9586
# Epoch 34/50
# 86937/86937 [==============================] - 544s 6ms/step - loss: 0.1372 - acc: 0.9601 - val_loss: 0.1497 - val_acc: 0.9590
# Epoch 35/50
# 83968/86937 [===========================>..] - ETA: 17s - loss: 0.1373 - acc: 0.9604
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 86937/86937 [==============================] - 545s 6ms/step - loss: 0.1360 - acc: 0.9602 - val_loss: 0.1506 - val_acc: 0.9588
# Epoch 38/50
# 41344/86937 [=============>................] - ETA: 4:32 - loss: 0.1353 - acc: 0.9602
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 86937/86937 [==============================] - 544s 6ms/step - loss: 0.1352 - acc: 0.9607 - val_loss: 0.1498 - val_acc: 0.9589
# Epoch 40/50
# 72000/86937 [=======================>......] - ETA: 1:29 - loss: 0.1355 - acc: 0.9610
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 86937/86937 [==============================] - 544s 6ms/step - loss: 0.1345 - acc: 0.9607 - val_loss: 0.1500 - val_acc: 0.9591
# Epoch 43/50
# 26880/86937 [========>.....................] - ETA: 5:59 - loss: 0.1381 - acc: 0.9593
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 86937/86937 [==============================] - 545s 6ms/step - loss: 0.1342 - acc: 0.9607 - val_loss: 0.1499 - val_acc: 0.9590
# Epoch 45/50
# 59648/86937 [===================>..........] - ETA: 2:42 - loss: 0.1350 - acc: 0.9611
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 86937/86937 [==============================] - 544s 6ms/step - loss: 0.1343 - acc: 0.9610 - val_loss: 0.1505 - val_acc: 0.9588
# Epoch 48/50
# 18112/86937 [=====>........................] - ETA: 6:51 - loss: 0.1361 - acc: 0.9592
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 86937/86937 [==============================] - 544s 6ms/step - loss: 0.1342 - acc: 0.9609 - val_loss: 0.1502 - val_acc: 0.9591
# Epoch 50/50
# 51296/86937 [================>.............] - ETA: 3:34 - loss: 0.1347 - acc: 0.9607
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# save the resnet 50 trained model for future reference
resnet_model_50.save("resnet_model_50")

# %%
#get resnet 34 performance metrics
from keras.applications.imagenet_utils import decode_predictions 
predictions = resnet_model_50.predict(X_test_new) 
#y_pred =(predictions>0.5)
y_pred =  (predictions>0.5) 
y_pred = y_pred.astype(int)
type(y_pred)
#label = decode_predictions(predictions)
get_classification_metric_resnet(y_test, y_pred)
# Out:
# precision= [0.93489763 0.96482917 1.        ]
# recall= [1.         0.99227362 0.        ]
# thresholds= [0 1]
# fscore 0.9783589693823088
# 0.9783589693823088

# %%
print('Generating results')
generate_results(y_test, predictions[:,1])
# Out:
# Generating results
# AUC: 0.859583

# %%
# list all data in history
print(history_resnet_50.history.keys())
# summarize history for accuracy
plt.plot(history_resnet_50.history['acc'])
plt.plot(history_resnet_50.history['val_acc'])
plt.title('model accuracy',fontsize=30)
plt.ylabel('accuracy',fontsize=30)
plt.xlabel('epoch',fontsize=30)
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history_resnet_50.history['loss'])
plt.plot(history_resnet_50.history['val_loss'])
plt.title('model loss',fontsize=30)
plt.ylabel('loss',fontsize=30)
plt.xlabel('epoch',fontsize=30)
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc', 'lr'])

# %%
#profile resnet 50 and visualize results
from util import profile
# analyze FLOPS
layer_name, layer_flops, inshape, weights = profile(resnet_model_50)
# visualize results
for name, flop, shape, weight in zip(layer_name, layer_flops, inshape, weights):
    print("layer:", name, shape, " MegaFLOPS:", flop/1e6, " MegaWeights:", weight/1e6)
# Out:
# layer: conv2d_54 (None, 1, 138, 1)  MegaFLOPS: 0.432832  MegaWeights: 0.0032
# layer: conv2d_55 (None, 1, 35, 64)  MegaFLOPS: 0.286784  MegaWeights: 0.00416
# layer: conv2d_56 (None, 1, 35, 64)  MegaFLOPS: 2.580544  MegaWeights: 0.036928
# layer: conv2d_58 (None, 1, 35, 64)  MegaFLOPS: 1.147136  MegaWeights: 0.01664
# layer: conv2d_57 (None, 1, 35, 64)  MegaFLOPS: 1.147136  MegaWeights: 0.01664
# layer: conv2d_59 (None, 1, 35, 256)  MegaFLOPS: 1.146944  MegaWeights: 0.016448
# layer: conv2d_60 (None, 1, 35, 64)  MegaFLOPS: 2.580544  MegaWeights: 0.036928
# layer: conv2d_61 (None, 1, 35, 64)  MegaFLOPS: 1.147136  MegaWeights: 0.01664
# layer: conv2d_62 (None, 1, 35, 256)  MegaFLOPS: 1.146944  MegaWeights: 0.016448
# layer: conv2d_63 (None, 1, 35, 64)  MegaFLOPS: 2.580544  MegaWeights: 0.036928
# layer: conv2d_64 (None, 1, 35, 64)  MegaFLOPS: 1.147136  MegaWeights: 0.01664
# layer: conv2d_65 (None, 1, 35, 256)  MegaFLOPS: 1.179776  MegaWeights: 0.032896
# layer: conv2d_66 (None, 1, 18, 128)  MegaFLOPS: 5.308544  MegaWeights: 0.147584
# layer: conv2d_68 (None, 1, 35, 256)  MegaFLOPS: 4.719104  MegaWeights: 0.131584
# layer: conv2d_67 (None, 1, 18, 128)  MegaFLOPS: 2.359808  MegaWeights: 0.066048
# layer: conv2d_69 (None, 1, 18, 512)  MegaFLOPS: 2.359424  MegaWeights: 0.065664
# layer: conv2d_70 (None, 1, 18, 128)  MegaFLOPS: 5.308544  MegaWeights: 0.147584
# layer: conv2d_71 (None, 1, 18, 128)  MegaFLOPS: 2.359808  MegaWeights: 0.066048
# layer: conv2d_72 (None, 1, 18, 512)  MegaFLOPS: 2.359424  MegaWeights: 0.065664
# layer: conv2d_73 (None, 1, 18, 128)  MegaFLOPS: 5.308544  MegaWeights: 0.147584
# layer: conv2d_74 (None, 1, 18, 128)  MegaFLOPS: 2.359808  MegaWeights: 0.066048
# layer: conv2d_75 (None, 1, 18, 512)  MegaFLOPS: 2.359424  MegaWeights: 0.065664
# layer: conv2d_76 (None, 1, 18, 128)  MegaFLOPS: 5.308544  MegaWeights: 0.147584
# layer: conv2d_77 (None, 1, 18, 128)  MegaFLOPS: 2.359808  MegaWeights: 0.066048
# layer: conv2d_78 (None, 1, 18, 512)  MegaFLOPS: 2.359552  MegaWeights: 0.131328
